# %% [markdown]
# 本程式碼請搭配文章「[在 Colab 上利用 Yolov3 框架和自有標住資料來訓練自己的物件辨識系統](http://bit.ly/2OAfpq0)」 一起服用。
#
# 其實原意是利用圖片辨識手遊的畫面，來幫我自動玩手遊練功。在找資料的時候，很多人都推薦 Yolov3，優點是非常快速，剛好利用在畫面變動巨大的手遊上。但使用遊戲畫面，可能只有我自己看得懂。所以這篇文章我用最普遍的貓和狗當作範例。能訓練貓和狗就能訓練自己其他的資料了。
#
# # 這篇文章會教你
# 在此範例中，我們將會訓練一個能偵測圖片中貓和狗的模型。你可以自由替換資料集，偵測自訂的物體。
#
# 除此之外，還有：
# * 利用 Colab 128G RAM GPU 來訓練你的 Yolo3 模型
# * 掛載 Google Drive 檔案到 Colab 檔案系統中
# * 將 PASCAL VOC 標籤格式轉換成 Yolo 用的標籤格式
# * 產生 Yolo 訓練需要的 cfg 設定檔案
# * 將訓練後的 weight 檔案同步至 Google Drive 中，避免遺失
# * 如何利用 weight 檔案來辨識圖片中的內容
#
# # 事前準備
#
# 在開始前，你需要先編譯好 Darknet 執行檔案。你可以參考我的另外一篇文章「[如何在 Colab 安裝 Darknet 框架訓練 YOLO v3 物件辨識並且最佳化 Colab 的訓練流程](http://bit.ly/33XjcEu)」，文章中會將編譯好的 Darknet 執行檔案放到 Google Drive目錄下。本文章將會利用這個執行檔案進行訓練。

# %% [markdown]
# ---

# %% [markdown]
# ## 將 Google Drive 掛載到 Colab 目錄下
#
# 掛載 Google Drive 的好處是不用每次都手動上傳或下載檔案，而且還能讓訓練好的模型檔案自動保存到 Google Drive。這樣就不會因為 Colab 中斷後就必須從頭訓練。

# %%
# 將 Google Drive 掛載到 Colab 目錄下
from google.colab import drive
drive.mount('/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /drive

# %%
# %cd /content/
# !git clone https://github.com/kriyeng/darknet/ darknet_source
# %cd darknet_source
# # 修改 Darknet 設定，符合 Colab 環境
# !sed -i "s/GPU=0/GPU=1/g" Makefile
# !sed -i "s/CUDNN=0/CUDNN=1/g" Makefile
# !sed -i "s/OPENCV=0/OPENCV=1/g" Makefile
# # 編譯
# !make
# # 將編譯完成的執行檔複製回 Google Drive
# !cp ./darknet /app/darknet
# !cp ./darknet /content/darknet
# %cd /content

# %% [markdown]
# # 準備資料集
#
# 您可以使用自己的資料夾。為了示範，這邊使用 [The Oxford-IIIT Pet Dataset](http://www.robots.ox.ac.uk/~vgg/data/pets/) 已經標注好的寵物資料來當作範例。我們會用到裡面的圖片檔以及 `annotations` 中的 `xml` 標註資料。

# %%
# %cd /content

# !wget http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# !wget http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz

# # 如果你已經把檔案下載到你的 Google Drive 就可以直接用複製的，速度會快一些
# # !cp /drive/My\ Drive/ColabDrive/The_Oxford_IIIT_Pet_Dataset/images.tar.gz /content/
# # !cp /drive/My\ Drive/ColabDrive/The_Oxford_IIIT_Pet_Dataset/annotations.tar.gz /content/

# # move image and label folder into pet_detection folder
# !mkdir /content/pet_detection
# !tar -xf images.tar.gz -C /content/pet_detection
# !tar -xf annotations.tar.gz
# !mv annotations/xmls /content/pet_detection/labels
# !rm -fr annotations
# Out:
# /content

# %% [markdown]
# ## 定義後來會用到的檔案路徑
#
# 路徑分為保存在 Colab 的，每次 Colab 被重置後就會消失。所以只放一些不重要的東西。
# 保存在 Google Drive 的檔案就是會被保存下來的，即使 Colab 被重置後，也不會消失；我們會把重要的東西存在這，例如設定檔、訓練到一半的模型等。

# %%
# define constants

# LOCAL_IMAGES_DIR_PATH = "/content/pet_detection/images"
# LOCAL_LABELS_DIR_PATH = "/content/pet_detection/labels"
LOCAL_IMAGES_DIR_PATH = "/drive/My\ Drive/Final_Project/data/images"
LOCAL_LABELS_DIR_PATH = "/drive/My\ Drive/Final_Project/data/labels"
LOCAL_YOLOS_DIR_PATH = "/content/pet_detection/yolos"
LOCAL_CFG_DIR_PATH = "/content/pet_detection/cfg"
GDRIVE_APP_BASE_DIR_REMOTE_PATH = "/drive/My\ Drive/train_yolo_with_custom_dataset_on_colab_101"

GDRIVE_APP_BASE_DIR_PATH = "/content/app"
GDRIVE_WEIGHTS_DIR_PATH = GDRIVE_APP_BASE_DIR_PATH+"/weights"
GDRIVE_CFG_DIR_PATH = GDRIVE_APP_BASE_DIR_PATH+"/cfg"
GITHUB_CODEBASE_DIR_PATH = "/content/train_yolo_with_custom_dataset_on_colab_101"
# GITHUB_CODEBASE_DIR_PATH = "/drive/My\ Drive/Final_Project/train_yolo_with_custom_dataset_on_colab_101"

GDRIVE_DARKNET_BIN_FILE_PATH = GITHUB_CODEBASE_DIR_PATH+"/darknet"

# %%
# load sample codes
# %cd /content
# !git clone https://github.com/wallat/train_yolo_with_custom_dataset_on_colab_101.git
# Out:
# /content
# Cloning into 'train_yolo_with_custom_dataset_on_colab_101'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 23 (delta 4), reused 19 (delta 3), pack-reused 0
# Unpacking objects: 100% (23/23), done.

# %%
# build the link to avoiding type in long path name everytime
# !ln -fs {GDRIVE_APP_BASE_DIR_REMOTE_PATH} {GDRIVE_APP_BASE_DIR_PATH}

# %%
# clean folders

import os
import shutil

shutil.rmtree(LOCAL_CFG_DIR_PATH, ignore_errors=True)
shutil.rmtree(LOCAL_YOLOS_DIR_PATH, ignore_errors=True)

os.makedirs(GDRIVE_APP_BASE_DIR_REMOTE_PATH.replace("\ ", " "), exist_ok=True)
os.makedirs(GDRIVE_CFG_DIR_PATH, exist_ok=True)
os.makedirs(GDRIVE_WEIGHTS_DIR_PATH, exist_ok=True)

os.makedirs(LOCAL_CFG_DIR_PATH, exist_ok=True)
os.makedirs(LOCAL_YOLOS_DIR_PATH, exist_ok=True)
# os.makedirs(GDRIVE_CFG_DIR_PATH, exist_ok=True)

# %%
LOCAL_IMAGES_DIR_PATH = "/drive/My Drive/Final_Project/data/images"
LOCAL_LABELS_DIR_PATH = "/drive/My Drive/Final_Project/data/labels"

# %% [markdown]
# ## 擷取出所有的標籤名稱
#
# 由於 darknet 框架會將物體名字全部轉成數字，我們需要先將物體名字全部擷取出來存在一份檔案中，當作之後的對照表。

# %%
# no \
# Convert VOC xmls into Yolo's format

import glob
import os
import re

labels = set()
for path in glob.glob(os.path.join(LOCAL_LABELS_DIR_PATH, "*.xml")):
    with open(path, 'r') as f:
        content = f.read()

    # extract label names
    matches = re.findall(r'<name>([\w_]+)<\/name>', content, flags=0)
    labels.update(matches)

# write label into file`
with open(os.path.join(GDRIVE_CFG_DIR_PATH, "obj.names"), 'w') as f:
    f.write("\n".join(labels))

print('Read in %d labels: %s' % (len(labels), ", ".join(labels)))
# Out:
# Read in 2 labels: raccoon, kangaroo

# %% [markdown]
# ## 將 VOC 格式的標記資料轉成 YOLO 的標記資料
#
# Yolo 不是使用標準的格式，原本的 VOC 標記格式需要轉換後才能使用在 darkent 框架上。
# 這邊就不詳細解釋如何轉換，對如何轉換的詳細規格可以參考 Yolo 官網 。我們直接使用我從 convert2Yolo 套件中擷取出來的片段程式碼來執行轉換，並把轉換的結果都放到 `/content/pet_detection/yolos` 目錄中。

# %%
# no \
import sys
sys.path.append(GITHUB_CODEBASE_DIR_PATH)

from Format import VOC, YOLO

voc = VOC()
yolo = YOLO(os.path.join(GDRIVE_CFG_DIR_PATH, "obj.names"))

flag, data = voc.parse(LOCAL_LABELS_DIR_PATH)
flag, data = yolo.generate(data)

flag, data = yolo.save(data,
    save_path=LOCAL_YOLOS_DIR_PATH,
    img_path=LOCAL_IMAGES_DIR_PATH, img_type=".jpg", manipast_path="./")
# Out:
# l ['raccoon', 'kangaroo']
#
# VOC Parsing:   |████████████████████████████████████████| 100.0% (364/364)  Complete
#
#
# YOLO Generating:|████████████████████████████████████████| 100.0% (364/364)  Complete
#
#
# YOLO Saving:   |████████████████████████████████████████| 100.0% (364/364)  Complete

# %%
LOCAL_IMAGES_DIR_PATH = "/drive/My\ Drive/Final_Project/data/images"
LOCAL_LABELS_DIR_PATH = "/drive/My\ Drive/Final_Project/data/labels"

# %%
# copy images into yolos folder
# !find $LOCAL_IMAGES_DIR_PATH -name "*.jpg" -exec cp {} /content/pet_detection/yolos \;

# from distutils.dir_util import copy_tree
# copy_tree(LOCAL_IMAGES_DIR_PATH, LOCAL_YOLOS_DIR_PATH)

# !cp {LOCAL_IMAGES_DIR_PATH}/*.jpg {LOCAL_YOLOS_DIR_PATH}

# %% [markdown]
# ## 準備訓練用的設定檔
#
# * `obj.names`：所有的物體標籤名稱，每一行一個。例如此例中只會有兩行，分別是 cat dog 。
# * `yolov3.cfg`：darknet 網路的設定檔，描述每一層網路應該要如何建立，以及建立多少 node 等。裡面有些數值需要根據你的訓練資料來個別設定。
# * `train.txt` `test.txt` ：這兩個檔案告訴 darknet 要到哪個路徑下找到訓練用的圖片。
# * `obj.data`：darknet 的主要設定檔案，告訴 darknet 其他的設定檔路徑。darknet 會一一去讀取其他的檔案。

# %%
# create the cfg file
# !cp {GITHUB_CODEBASE_DIR_PATH}/darknet_cfg/yolov3.cfg {GDRIVE_CFG_DIR_PATH}/yolov3.cfg

# fetch label_names
with open(os.path.join(GDRIVE_CFG_DIR_PATH, "obj.names"), 'r') as f:
  f_content = f.read()
label_names = f_content.strip().splitlines()

# update the cfg file
with open(os.path.join(GDRIVE_CFG_DIR_PATH, "yolov3.cfg"), 'r') as f:
  content = f.read()
with open(os.path.join(GDRIVE_CFG_DIR_PATH, "yolov3.cfg"), 'w') as f:
  num_max_batches = len(label_names)*5000
  content = content.replace("%NUM_CLASSES%", str(len(label_names)))
  content = content.replace("%NUM_MAX_BATCHES%", str(num_max_batches))
  content = content.replace("%NUM_MAX_BATCHES_80%", str(int(num_max_batches*0.8)))
  content = content.replace("%NUM_MAX_BATCHES_90%", str(int(num_max_batches*0.9)))
  content = content.replace("%NUM_CONVOLUTIONAL_FILTERS%", str((len(label_names)+5)*3))

  # content = content.replace("%max_batches = 4000%", "max_batches = 10000")

  f.write(content)

# %%
# create train and test files
import random
import glob

txt_paths = glob.glob(os.path.join(LOCAL_YOLOS_DIR_PATH, "*.txt"))

random.shuffle(txt_paths)
num_train_images = int(len(txt_paths)*0.8)

assert num_train_images>0, "There's no training images in folder %s" % (LOCAL_YOLOS_DIR_PATH)

with open(os.path.join(GDRIVE_CFG_DIR_PATH, "train.txt"), 'w') as f:
  for path in txt_paths[:num_train_images]:
    f.write("%s/%s\n" % (LOCAL_YOLOS_DIR_PATH, os.path.basename(path).replace(".txt", ".jpg")))
with open(os.path.join(GDRIVE_CFG_DIR_PATH, "test.txt"), 'w') as f:
  for path in txt_paths[num_train_images:]:
    f.write("%s/%s\n" % (LOCAL_YOLOS_DIR_PATH, os.path.basename(path).replace(".txt", ".jpg")))

# create obj
with open(os.path.join(GDRIVE_CFG_DIR_PATH, "obj.data"), 'w') as f:
  f.write("classes=%d\n" % (len(label_names)))
  f.write("train=%s/train.txt\n" % (GDRIVE_CFG_DIR_PATH))
  f.write("valid=%s/test.txt\n" % (GDRIVE_CFG_DIR_PATH))
  f.write("names=%s/obj.names\n" % (GDRIVE_CFG_DIR_PATH))
  f.write("backup=%s\n" % (GDRIVE_WEIGHTS_DIR_PATH))

# %% [markdown]
# ## 準備 darkent 執行檔
#
# 我們直接從之前已經編譯好的檔案複製過來就好，不用每次都重頭編譯那實在是太~花~時~間~了~。編譯的方法請見 「[如何在 Colab 安裝 Darknet 框架訓練 YOLO v3 物件辨識並且最佳化 Colab 的訓練流程](http://bit.ly/33XjcEu)」這邊文章。

# %%
# copy the pretrained darknet bin file
# !cp {GDRIVE_DARKNET_BIN_FILE_PATH} /content/
assert os.path.isfile("/content/darknet"), 'Cannot copy from %s to /content' % (GDRIVE_DARKNET_BIN_FILE_PATH)

# !chmod +x /content/darknet

# %%
# !apt install gcc-5 g++-5 -y
# !ln -s /usr/bin/gcc-5 /usr/local/cuda/bin/gcc 
# !ln -s /usr/bin/g++-5 /usr/local/cuda/bin/g++

# %% [markdown]
# ## （可選）使用 darknet 預先訓練的基底模型
#
# Darknet 也好心的提供了預先訓練的模型，以此為基底，可以讓後來的訓練比較快達到較好的辨識率。但前提是你的圖片都是常見的圖片，例如一般照片、場景照片等；如果是一些遊戲畫面很少見的，從 0 開始訓練可能會達到比較好的效果。

# %%
# Use the pre-trained weights to speed up the training speed
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2020-02-24 14:11:25--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M   328KB/s    in 8m 10s
#
# 2020-02-24 14:19:37 (324 KB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# # 終於可以開始訓練模型了～
#
# 上面的步驟看起來很多，但其實只要寫好一次，之後每次訓練時只要換上自己要的資料夾，然後按 `Run all` 就可以了。
#
# 這邊提供兩條指令：
#
# 1. 是從 YOLO Pre-trained model 開始訓練，如果你的資料集是一般照片，那用這個效果會比較好。
#
# 2. 是從上次訓練的中斷點繼續往下訓練；指令會讀取資料夾內的 weight 檔案，從上次中斷點繼續訓練下去。適合從 0 開始訓練或是被 Colab 中斷後重新開始訓練。

# %%
# train the model
# !./darknet detector train {GDRIVE_CFG_DIR_PATH}/obj.data {GDRIVE_CFG_DIR_PATH}/yolov3.cfg darknet53.conv.74 -dont_show
# !./darknet detector train {GDRIVE_CFG_DIR_PATH}/obj.data {GDRIVE_CFG_DIR_PATH}/yolov3.cfg darknet53.conv.74  -dont_show | grep "avg loss"
# !./darknet detector train {GDRIVE_CFG_DIR_PATH}/obj.data {GDRIVE_CFG_DIR_PATH}/yolov3.cfg {GDRIVE_WEIGHTS_DIR_PATH}/yolov3_last.weights  -dont_show | grep "avg loss"
# Out:
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32 0.299 BF
#    1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64 1.595 BF
#    2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32 0.177 BF
#    3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128 1.595 BF
#    6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#    7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#   10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   104 x 104 x 128   ->    52 x  52 x 256 1.595 BF
#   13 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   14 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   15 Shortcut Layer: 12
#   16 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   17 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   18 Shortcut Layer: 15
#   19 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   20 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   21 Shortcut Layer: 18
#   22 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   23 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   24 Shortcut Layer: 21
#   25 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   26 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   27 Shortcut Layer: 24
#   28 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   29 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   30 Shortcut Layer: 27
#   31 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   32 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   33 Shortcut Layer: 30
#   34 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   35 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   36 Shortcut Layer: 33
#   37 conv    512  3 x 3 / 2    52 x  52 x 256   ->    26 x  26 x 512 1.595 BF
#   38 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   39 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   40 Shortcut Layer: 37
#   41 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   42 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   43 Shortcut Layer: 40
#   44 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   45 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   46 Shortcut Layer: 43
#   47 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   48 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   49 Shortcut Layer: 46
#   50 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   51 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   52 Shortcut Layer: 49
#   53 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   54 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   55 Shortcut Layer: 52
#   56 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   57 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   58 Shortcut Layer: 55
#   59 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   60 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   61 Shortcut Layer: 58
#   62 conv   1024  3 x 3 / 2    26 x  26 x 512   ->    13 x  13 x1024 1.595 BF
#   63 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   64 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   65 Shortcut Layer: 62
#   66 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   67 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   68 Shortcut Layer: 65
#   69 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   70 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   71 Shortcut Layer: 68
#   72 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   73 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   74 Shortcut Layer: 71
#   75 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   76 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   77 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   78 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   79 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   80 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   81 conv     21  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x  21 0.007 BF
#   82 yolo
#   83 route  79
#   84 conv    256  1 x 1 / 1    13 x  13 x 512   ->    13 x  13 x 256 0.044 BF
#   85 upsample            2x    13 x  13 x 256   ->    26 x  26 x 256
#   86 route  85 61
#   87 conv    256  1 x 1 / 1    26 x  26 x 768   ->    26 x  26 x 256 0.266 BF
#   88 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   89 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   90 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   91 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   92 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   93 conv     21  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x  21 0.015 BF
#   94 yolo
#   95 route  91
#   96 conv    128  1 x 1 / 1    26 x  26 x 256   ->    26 x  26 x 128 0.044 BF
#   97 upsample            2x    26 x  26 x 128   ->    52 x  52 x 128
#   98 route  97 36
#   99 conv    128  1 x 1 / 1    52 x  52 x 384   ->    52 x  52 x 128 0.266 BF
#  100 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#  101 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#  102 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#  103 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#  104 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#  105 conv     21  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x  21 0.029 BF
#  106 yolo
# Total BFLOPS 65.297
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from /content/app/weights/yolov3_last.weights...Done!
#  8601: 0.056693, 0.056693 avg loss, 0.000100 rate, 5.143708 seconds, 550464 images
#  8602: 0.059751, 0.056999 avg loss, 0.000100 rate, 5.183641 seconds, 550528 images
#  8603: 0.045597, 0.055859 avg loss, 0.000100 rate, 5.277372 seconds, 550592 images
#  8604: 0.071932, 0.057466 avg loss, 0.000100 rate, 5.278775 seconds, 550656 images
#  8605: 0.045003, 0.056220 avg loss, 0.000100 rate, 5.279928 seconds, 550720 images
#  8606: 0.048800, 0.055478 avg loss, 0.000100 rate, 5.270639 seconds, 550784 images
#  8607: 0.052906, 0.055221 avg loss, 0.000100 rate, 5.269558 seconds, 550848 images
#  8608: 0.047261, 0.054425 avg loss, 0.000100 rate, 5.278348 seconds, 550912 images
#  8609: 0.073923, 0.056375 avg loss, 0.000100 rate, 5.296629 seconds, 550976 images
# Premature end of JPEG file
#  8610: 0.032358, 0.053973 avg loss, 0.000100 rate, 5.265186 seconds, 551040 images
# Premature end of JPEG file
#  8611: 0.044514, 0.053027 avg loss, 0.000100 rate, 2.030619 seconds, 551104 images
#  8612: 0.039779, 0.051702 avg loss, 0.000100 rate, 2.085970 seconds, 551168 images
#  8613: 0.036565, 0.050188 avg loss, 0.000100 rate, 2.092092 seconds, 551232 images
#  8614: 0.064522, 0.051622 avg loss, 0.000100 rate, 2.090262 seconds, 551296 images
#  8615: 0.054160, 0.051876 avg loss, 0.000100 rate, 2.091032 seconds, 551360 images
# Premature end of JPEG file
#  8616: 0.043660, 0.051054 avg loss, 0.000100 rate, 2.103730 seconds, 551424 images
# Premature end of JPEG file
#  8617: 0.028036, 0.048752 avg loss, 0.000100 rate, 2.083872 seconds, 551488 images
# Premature end of JPEG file
#  8618: 0.067727, 0.050650 avg loss, 0.000100 rate, 2.095647 seconds, 551552 images
# Premature end of JPEG file
#  8619: 0.039414, 0.049526 avg loss, 0.000100 rate, 2.092029 seconds, 551616 images
#  8620: 0.055000, 0.050074 avg loss, 0.000100 rate, 2.099316 seconds, 551680 images
#  8621: 0.030163, 0.048083 avg loss, 0.000100 rate, 2.028562 seconds, 551744 images
#  8622: 0.069667, 0.050241 avg loss, 0.000100 rate, 2.095483 seconds, 551808 images
#  8623: 0.032840, 0.048501 avg loss, 0.000100 rate, 2.110344 seconds, 551872 images
#  8624: 0.026456, 0.046296 avg loss, 0.000100 rate, 2.086075 seconds, 551936 images
#  8625: 0.037245, 0.045391 avg loss, 0.000100 rate, 2.093724 seconds, 552000 images
#  8626: 0.073555, 0.048208 avg loss, 0.000100 rate, 2.099025 seconds, 552064 images
#  8627: 0.044975, 0.047884 avg loss, 0.000100 rate, 2.091235 seconds, 552128 images
#  8628: 0.039675, 0.047063 avg loss, 0.000100 rate, 2.089781 seconds, 552192 images
#  8629: 0.048083, 0.047165 avg loss, 0.000100 rate, 2.090659 seconds, 552256 images
#  8630: 0.063380, 0.048787 avg loss, 0.000100 rate, 2.098773 seconds, 552320 images
#  8631: 0.038424, 0.047751 avg loss, 0.000100 rate, 4.362327 seconds, 552384 images
#  8632: 0.039939, 0.046969 avg loss, 0.000100 rate, 4.499676 seconds, 552448 images
#  8633: 0.030374, 0.045310 avg loss, 0.000100 rate, 4.520897 seconds, 552512 images
#  8634: 0.038433, 0.044622 avg loss, 0.000100 rate, 4.499108 seconds, 552576 images
#  8635: 0.044017, 0.044562 avg loss, 0.000100 rate, 4.508433 seconds, 552640 images
#  8636: 0.037982, 0.043904 avg loss, 0.000100 rate, 4.527337 seconds, 552704 images
#  8637: 0.034898, 0.043003 avg loss, 0.000100 rate, 4.501673 seconds, 552768 images
#  8638: 0.045958, 0.043299 avg loss, 0.000100 rate, 4.511164 seconds, 552832 images
#  8639: 0.049449, 0.043914 avg loss, 0.000100 rate, 4.500484 seconds, 552896 images
#  8640: 0.064807, 0.046003 avg loss, 0.000100 rate, 4.542462 seconds, 552960 images
# Premature end of JPEG file
#  8641: 0.030137, 0.044416 avg loss, 0.000100 rate, 2.021169 seconds, 553024 images
#  8642: 0.056743, 0.045649 avg loss, 0.000100 rate, 2.097800 seconds, 553088 images
#  8643: 0.033492, 0.044433 avg loss, 0.000100 rate, 2.088592 seconds, 553152 images
#  8644: 0.068075, 0.046797 avg loss, 0.000100 rate, 2.090585 seconds, 553216 images
#  8645: 0.041406, 0.046258 avg loss, 0.000100 rate, 2.097269 seconds, 553280 images
#  8646: 0.071917, 0.048824 avg loss, 0.000100 rate, 2.092143 seconds, 553344 images
#  8647: 0.059093, 0.049851 avg loss, 0.000100 rate, 2.103525 seconds, 553408 images
#  8648: 0.046461, 0.049512 avg loss, 0.000100 rate, 2.096693 seconds, 553472 images
#  8649: 0.058103, 0.050371 avg loss, 0.000100 rate, 2.090456 seconds, 553536 images
# Premature end of JPEG file
#  8650: 0.040485, 0.049382 avg loss, 0.000100 rate, 2.101234 seconds, 553600 images
#  8651: 0.040206, 0.048465 avg loss, 0.000100 rate, 4.617839 seconds, 553664 images
# Premature end of JPEG file
#  8652: 0.063171, 0.049935 avg loss, 0.000100 rate, 4.758779 seconds, 553728 images
#  8653: 0.045901, 0.049532 avg loss, 0.000100 rate, 4.754672 seconds, 553792 images
#  8654: 0.030467, 0.047625 avg loss, 0.000100 rate, 4.743692 seconds, 553856 images
#  8655: 0.053286, 0.048192 avg loss, 0.000100 rate, 4.729829 seconds, 553920 images
#  8656: 0.048573, 0.048230 avg loss, 0.000100 rate, 4.738710 seconds, 553984 images
#  8657: 0.036636, 0.047070 avg loss, 0.000100 rate, 4.756966 seconds, 554048 images
#  8658: 0.035805, 0.045944 avg loss, 0.000100 rate, 4.751681 seconds, 554112 images
# Premature end of JPEG file
#  8659: 0.050102, 0.046360 avg loss, 0.000100 rate, 4.744638 seconds, 554176 images
#  8660: 0.041550, 0.045879 avg loss, 0.000100 rate, 4.756755 seconds, 554240 images
#  8661: 0.039909, 0.045282 avg loss, 0.000100 rate, 2.233243 seconds, 554304 images
# Premature end of JPEG file
#  8662: 0.048111, 0.045565 avg loss, 0.000100 rate, 2.307680 seconds, 554368 images
#  8663: 0.077507, 0.048759 avg loss, 0.000100 rate, 2.323761 seconds, 554432 images
# Premature end of JPEG file
#  8664: 0.024383, 0.046321 avg loss, 0.000100 rate, 2.317362 seconds, 554496 images
#  8665: 0.020668, 0.043756 avg loss, 0.000100 rate, 2.307434 seconds, 554560 images
#  8666: 0.022112, 0.041592 avg loss, 0.000100 rate, 2.303293 seconds, 554624 images
# Premature end of JPEG file
#  8667: 0.026997, 0.040132 avg loss, 0.000100 rate, 2.316009 seconds, 554688 images
#  8668: 0.053390, 0.041458 avg loss, 0.000100 rate, 2.307413 seconds, 554752 images
#  8669: 0.046845, 0.041997 avg loss, 0.000100 rate, 2.321867 seconds, 554816 images
# Premature end of JPEG file
#  8670: 0.029902, 0.040787 avg loss, 0.000100 rate, 2.309485 seconds, 554880 images
#  8671: 0.029441, 0.039653 avg loss, 0.000100 rate, 2.793974 seconds, 554944 images
#  8672: 0.027941, 0.038481 avg loss, 0.000100 rate, 2.911412 seconds, 555008 images
#  8673: 0.019388, 0.036572 avg loss, 0.000100 rate, 2.876959 seconds, 555072 images
# Premature end of JPEG file
#  8674: 0.027483, 0.035663 avg loss, 0.000100 rate, 2.873217 seconds, 555136 images
#  8675: 0.025825, 0.034679 avg loss, 0.000100 rate, 2.889151 seconds, 555200 images
#  8676: 0.024507, 0.033662 avg loss, 0.000100 rate, 2.898768 seconds, 555264 images
#  8677: 0.029865, 0.033282 avg loss, 0.000100 rate, 2.898384 seconds, 555328 images
#  8678: 0.037837, 0.033738 avg loss, 0.000100 rate, 2.881929 seconds, 555392 images
#  8679: 0.030546, 0.033419 avg loss, 0.000100 rate, 2.891099 seconds, 555456 images
#  8680: 0.028035, 0.032880 avg loss, 0.000100 rate, 2.915008 seconds, 555520 images
#  8681: 0.028399, 0.032432 avg loss, 0.000100 rate, 2.597446 seconds, 555584 images
#  8682: 0.027793, 0.031968 avg loss, 0.000100 rate, 2.692869 seconds, 555648 images
#  8683: 0.042273, 0.032999 avg loss, 0.000100 rate, 2.693406 seconds, 555712 images
#  8684: 0.038159, 0.033515 avg loss, 0.000100 rate, 2.695813 seconds, 555776 images
# Premature end of JPEG file
#  8685: 0.021623, 0.032326 avg loss, 0.000100 rate, 2.689128 seconds, 555840 images
#  8686: 0.033070, 0.032400 avg loss, 0.000100 rate, 2.698313 seconds, 555904 images
# Premature end of JPEG file
#  8687: 0.037386, 0.032899 avg loss, 0.000100 rate, 2.691233 seconds, 555968 images
#  8688: 0.018106, 0.031419 avg loss, 0.000100 rate, 2.692908 seconds, 556032 images
#  8689: 0.039255, 0.032203 avg loss, 0.000100 rate, 2.690797 seconds, 556096 images
#  8690: 0.030695, 0.032052 avg loss, 0.000100 rate, 2.693401 seconds, 556160 images
#  8691: 0.031582, 0.032005 avg loss, 0.000100 rate, 4.375802 seconds, 556224 images
#  8692: 0.030636, 0.031868 avg loss, 0.000100 rate, 4.504754 seconds, 556288 images
#  8693: 0.035064, 0.032188 avg loss, 0.000100 rate, 4.487494 seconds, 556352 images
#  8694: 0.022611, 0.031230 avg loss, 0.000100 rate, 4.492858 seconds, 556416 images
# Premature end of JPEG file
#  8695: 0.049445, 0.033052 avg loss, 0.000100 rate, 4.489507 seconds, 556480 images
#  8696: 0.033982, 0.033145 avg loss, 0.000100 rate, 4.513781 seconds, 556544 images
# Premature end of JPEG file
#  8697: 0.040768, 0.033907 avg loss, 0.000100 rate, 4.506166 seconds, 556608 images
# Premature end of JPEG file
#  8698: 0.033804, 0.033897 avg loss, 0.000100 rate, 4.513361 seconds, 556672 images
#  8699: 0.045128, 0.035020 avg loss, 0.000100 rate, 4.499449 seconds, 556736 images
# Saving weights to /content/app/weights/yolov3_last.weights
#  8700: 0.029671, 0.034485 avg loss, 0.000100 rate, 4.504017 seconds, 556800 images
#  8701: 0.040179, 0.035054 avg loss, 0.000100 rate, 2.232538 seconds, 556864 images
#  8702: 0.034245, 0.034973 avg loss, 0.000100 rate, 2.337098 seconds, 556928 images
#  8703: 0.042207, 0.035697 avg loss, 0.000100 rate, 2.336498 seconds, 556992 images
#  8704: 0.046169, 0.036744 avg loss, 0.000100 rate, 2.326515 seconds, 557056 images
#  8705: 0.055354, 0.038605 avg loss, 0.000100 rate, 2.335845 seconds, 557120 images
#  8706: 0.029058, 0.037650 avg loss, 0.000100 rate, 2.309359 seconds, 557184 images
#  8707: 0.070078, 0.040893 avg loss, 0.000100 rate, 2.310056 seconds, 557248 images
#  8708: 0.028057, 0.039609 avg loss, 0.000100 rate, 2.307264 seconds, 557312 images
# Premature end of JPEG file
#  8709: 0.025669, 0.038215 avg loss, 0.000100 rate, 2.301838 seconds, 557376 images
# Premature end of JPEG file
#  8710: 0.046439, 0.039038 avg loss, 0.000100 rate, 2.311914 seconds, 557440 images
# Premature end of JPEG file
# Premature end of JPEG file
# Premature end of JPEG file
#  8711: 0.034957, 0.038630 avg loss, 0.000100 rate, 2.027205 seconds, 557504 images
#  8712: 0.047427, 0.039509 avg loss, 0.000100 rate, 2.098580 seconds, 557568 images
#  8713: 0.042028, 0.039761 avg loss, 0.000100 rate, 2.098480 seconds, 557632 images
#  8714: 0.045549, 0.040340 avg loss, 0.000100 rate, 2.097516 seconds, 557696 images
#  8715: 0.049576, 0.041264 avg loss, 0.000100 rate, 2.096244 seconds, 557760 images
#  8716: 0.032624, 0.040400 avg loss, 0.000100 rate, 2.097829 seconds, 557824 images
#  8717: 0.082366, 0.044596 avg loss, 0.000100 rate, 2.096925 seconds, 557888 images
#  8718: 0.049503, 0.045087 avg loss, 0.000100 rate, 2.103394 seconds, 557952 images
#  8719: 0.050946, 0.045673 avg loss, 0.000100 rate, 2.100302 seconds, 558016 images
#  8720: 0.031220, 0.044228 avg loss, 0.000100 rate, 2.102753 seconds, 558080 images
#  8721: 0.052139, 0.045019 avg loss, 0.000100 rate, 2.596435 seconds, 558144 images
#  8722: 0.085210, 0.049038 avg loss, 0.000100 rate, 2.699374 seconds, 558208 images
# Premature end of JPEG file
#  8723: 0.027803, 0.046914 avg loss, 0.000100 rate, 2.689905 seconds, 558272 images
#  8724: 0.030749, 0.045298 avg loss, 0.000100 rate, 2.697608 seconds, 558336 images
#  8725: 0.045393, 0.045307 avg loss, 0.000100 rate, 2.691914 seconds, 558400 images
#  8726: 0.030704, 0.043847 avg loss, 0.000100 rate, 2.688322 seconds, 558464 images
#  8727: 0.032487, 0.042711 avg loss, 0.000100 rate, 2.700394 seconds, 558528 images
#  8728: 0.039540, 0.042394 avg loss, 0.000100 rate, 2.684872 seconds, 558592 images
#  8729: 0.035560, 0.041711 avg loss, 0.000100 rate, 2.697536 seconds, 558656 images
#  8730: 0.030280, 0.040568 avg loss, 0.000100 rate, 2.698504 seconds, 558720 images
#  8731: 0.039341, 0.040445 avg loss, 0.000100 rate, 3.587828 seconds, 558784 images
#  8732: 0.023410, 0.038741 avg loss, 0.000100 rate, 3.708762 seconds, 558848 images
#  8733: 0.038660, 0.038733 avg loss, 0.000100 rate, 3.665558 seconds, 558912 images
#  8734: 0.035552, 0.038415 avg loss, 0.000100 rate, 3.713112 seconds, 558976 images
#  8735: 0.072213, 0.041795 avg loss, 0.000100 rate, 3.704728 seconds, 559040 images
#  8736: 0.030667, 0.040682 avg loss, 0.000100 rate, 3.722790 seconds, 559104 images
#  8737: 0.034485, 0.040062 avg loss, 0.000100 rate, 3.688137 seconds, 559168 images
#  8738: 0.041628, 0.040219 avg loss, 0.000100 rate, 3.712874 seconds, 559232 images
#  8739: 0.030798, 0.039277 avg loss, 0.000100 rate, 3.691766 seconds, 559296 images
#  8740: 0.035963, 0.038945 avg loss, 0.000100 rate, 3.693994 seconds, 559360 images
#  8741: 0.052627, 0.040314 avg loss, 0.000100 rate, 3.620145 seconds, 559424 images
#  8742: 0.024457, 0.038728 avg loss, 0.000100 rate, 3.694781 seconds, 559488 images
#  8743: 0.049328, 0.039788 avg loss, 0.000100 rate, 3.724949 seconds, 559552 images
#  8744: 0.047088, 0.040518 avg loss, 0.000100 rate, 3.707625 seconds, 559616 images
# Premature end of JPEG file
#  8745: 0.044909, 0.040957 avg loss, 0.000100 rate, 3.693650 seconds, 559680 images
# Premature end of JPEG file
#  8746: 0.048058, 0.041667 avg loss, 0.000100 rate, 3.699212 seconds, 559744 images
#  8747: 0.033272, 0.040828 avg loss, 0.000100 rate, 3.689116 seconds, 559808 images
#  8748: 0.036492, 0.040394 avg loss, 0.000100 rate, 3.696607 seconds, 559872 images
#  8749: 0.024989, 0.038854 avg loss, 0.000100 rate, 3.690817 seconds, 559936 images
# Premature end of JPEG file
# Premature end of JPEG file
#  8750: 0.048798, 0.039848 avg loss, 0.000100 rate, 3.706836 seconds, 560000 images
#  8751: 0.042146, 0.040078 avg loss, 0.000100 rate, 3.293041 seconds, 560064 images
# Premature end of JPEG file
#  8752: 0.026858, 0.038756 avg loss, 0.000100 rate, 3.403988 seconds, 560128 images
#  8753: 0.023962, 0.037276 avg loss, 0.000100 rate, 3.403624 seconds, 560192 images
#  8754: 0.034601, 0.037009 avg loss, 0.000100 rate, 3.427985 seconds, 560256 images
#  8755: 0.030671, 0.036375 avg loss, 0.000100 rate, 3.404824 seconds, 560320 images
# Premature end of JPEG file
#  8756: 0.041231, 0.036861 avg loss, 0.000100 rate, 3.410176 seconds, 560384 images
#  8757: 0.024730, 0.035648 avg loss, 0.000100 rate, 3.408461 seconds, 560448 images
#  8758: 0.053381, 0.037421 avg loss, 0.000100 rate, 3.434124 seconds, 560512 images
#  8759: 0.032398, 0.036919 avg loss, 0.000100 rate, 3.412541 seconds, 560576 images
# Premature end of JPEG file
#  8760: 0.049243, 0.038151 avg loss, 0.000100 rate, 3.406818 seconds, 560640 images
#  8761: 0.049649, 0.039301 avg loss, 0.000100 rate, 4.614298 seconds, 560704 images
# Premature end of JPEG file
#  8762: 0.042959, 0.039667 avg loss, 0.000100 rate, 4.754512 seconds, 560768 images
#  8763: 0.048710, 0.040571 avg loss, 0.000100 rate, 4.759752 seconds, 560832 images
#  8764: 0.054200, 0.041934 avg loss, 0.000100 rate, 4.761566 seconds, 560896 images
#  8765: 0.027871, 0.040528 avg loss, 0.000100 rate, 4.751525 seconds, 560960 images
#  8766: 0.039693, 0.040444 avg loss, 0.000100 rate, 4.751105 seconds, 561024 images
#  8767: 0.046043, 0.041004 avg loss, 0.000100 rate, 4.734633 seconds, 561088 images
#  8768: 0.053599, 0.042263 avg loss, 0.000100 rate, 4.767772 seconds, 561152 images
#  8769: 0.098743, 0.047911 avg loss, 0.000100 rate, 4.750616 seconds, 561216 images
#  8770: 0.035504, 0.046671 avg loss, 0.000100 rate, 4.754601 seconds, 561280 images
#  8771: 0.033365, 0.045340 avg loss, 0.000100 rate, 5.123509 seconds, 561344 images
#  8772: 0.040329, 0.044839 avg loss, 0.000100 rate, 5.278211 seconds, 561408 images
#  8773: 0.050570, 0.045412 avg loss, 0.000100 rate, 5.285572 seconds, 561472 images
#  8774: 0.045939, 0.045465 avg loss, 0.000100 rate, 5.299480 seconds, 561536 images
#  8775: 0.041977, 0.045116 avg loss, 0.000100 rate, 5.273753 seconds, 561600 images
#  8776: 0.046670, 0.045271 avg loss, 0.000100 rate, 5.307418 seconds, 561664 images
#  8777: 0.041940, 0.044938 avg loss, 0.000100 rate, 5.258938 seconds, 561728 images
#  8778: 0.050591, 0.045503 avg loss, 0.000100 rate, 5.291551 seconds, 561792 images
#  8779: 0.061782, 0.047131 avg loss, 0.000100 rate, 5.281648 seconds, 561856 images
#  8780: 0.031764, 0.045595 avg loss, 0.000100 rate, 5.274173 seconds, 561920 images
#  8781: 0.042735, 0.045309 avg loss, 0.000100 rate, 2.263892 seconds, 561984 images
#  8782: 0.050802, 0.045858 avg loss, 0.000100 rate, 2.307129 seconds, 562048 images
#  8783: 0.064456, 0.047718 avg loss, 0.000100 rate, 2.327397 seconds, 562112 images
# Premature end of JPEG file
#  8784: 0.033899, 0.046336 avg loss, 0.000100 rate, 2.314548 seconds, 562176 images
#  8785: 0.058631, 0.047565 avg loss, 0.000100 rate, 2.313896 seconds, 562240 images
#  8786: 0.032535, 0.046062 avg loss, 0.000100 rate, 2.310745 seconds, 562304 images
#  8787: 0.038155, 0.045272 avg loss, 0.000100 rate, 2.314197 seconds, 562368 images
#  8788: 0.054073, 0.046152 avg loss, 0.000100 rate, 2.319683 seconds, 562432 images
# Premature end of JPEG file
#  8789: 0.036860, 0.045223 avg loss, 0.000100 rate, 2.317064 seconds, 562496 images
# Premature end of JPEG file
#  8790: 0.073347, 0.048035 avg loss, 0.000100 rate, 2.310041 seconds, 562560 images
#  8791: 0.061540, 0.049386 avg loss, 0.000100 rate, 4.403669 seconds, 562624 images
#  8792: 0.064156, 0.050863 avg loss, 0.000100 rate, 4.511327 seconds, 562688 images
#  8793: 0.043866, 0.050163 avg loss, 0.000100 rate, 4.519483 seconds, 562752 images
#  8794: 0.057168, 0.050863 avg loss, 0.000100 rate, 4.547457 seconds, 562816 images
#  8795: 0.051574, 0.050934 avg loss, 0.000100 rate, 4.514473 seconds, 562880 images
# Premature end of JPEG file
# Premature end of JPEG file
#  8796: 0.067835, 0.052625 avg loss, 0.000100 rate, 4.518285 seconds, 562944 images
#  8797: 0.033393, 0.050701 avg loss, 0.000100 rate, 4.525526 seconds, 563008 images
#  8798: 0.033692, 0.049000 avg loss, 0.000100 rate, 4.526648 seconds, 563072 images
#  8799: 0.048153, 0.048916 avg loss, 0.000100 rate, 4.513474 seconds, 563136 images
# Saving weights to /content/app/weights/yolov3_last.weights
#  8800: 0.027092, 0.046733 avg loss, 0.000100 rate, 4.512339 seconds, 563200 images
#  8801: 0.057324, 0.047792 avg loss, 0.000100 rate, 3.609367 seconds, 563264 images
#  8802: 0.017767, 0.044790 avg loss, 0.000100 rate, 3.700006 seconds, 563328 images
# Premature end of JPEG file
#  8803: 0.031566, 0.043467 avg loss, 0.000100 rate, 3.706528 seconds, 563392 images
#  8804: 0.030555, 0.042176 avg loss, 0.000100 rate, 3.723309 seconds, 563456 images
#  8805: 0.045944, 0.042553 avg loss, 0.000100 rate, 3.717140 seconds, 563520 images
#  8806: 0.036847, 0.041982 avg loss, 0.000100 rate, 3.694262 seconds, 563584 images
#  8807: 0.034316, 0.041216 avg loss, 0.000100 rate, 3.702791 seconds, 563648 images
#  8808: 0.031327, 0.040227 avg loss, 0.000100 rate, 3.694234 seconds, 563712 images
#  8809: 0.065834, 0.042788 avg loss, 0.000100 rate, 3.702851 seconds, 563776 images
#  8810: 0.034525, 0.041961 avg loss, 0.000100 rate, 3.706698 seconds, 563840 images
#  8811: 0.027353, 0.040501 avg loss, 0.000100 rate, 3.299951 seconds, 563904 images
#  8812: 0.022575, 0.038708 avg loss, 0.000100 rate, 3.413699 seconds, 563968 images
#  8813: 0.023966, 0.037234 avg loss, 0.000100 rate, 3.430117 seconds, 564032 images
#  8814: 0.033793, 0.036890 avg loss, 0.000100 rate, 3.424243 seconds, 564096 images
# Premature end of JPEG file
#  8815: 0.019073, 0.035108 avg loss, 0.000100 rate, 3.411709 seconds, 564160 images
#  8816: 0.019907, 0.033588 avg loss, 0.000100 rate, 3.412628 seconds, 564224 images
#  8817: 0.027245, 0.032954 avg loss, 0.000100 rate, 3.416339 seconds, 564288 images
#  8818: 0.021322, 0.031790 avg loss, 0.000100 rate, 3.419957 seconds, 564352 images
#  8819: 0.025129, 0.031124 avg loss, 0.000100 rate, 3.408314 seconds, 564416 images
#  8820: 0.028226, 0.030834 avg loss, 0.000100 rate, 3.420674 seconds, 564480 images
#  8821: 0.050398, 0.032791 avg loss, 0.000100 rate, 2.038425 seconds, 564544 images
#  8822: 0.032490, 0.032761 avg loss, 0.000100 rate, 2.087434 seconds, 564608 images
#  8823: 0.050246, 0.034509 avg loss, 0.000100 rate, 2.099689 seconds, 564672 images
#  8824: 0.057737, 0.036832 avg loss, 0.000100 rate, 2.095882 seconds, 564736 images
#  8825: 0.035929, 0.036742 avg loss, 0.000100 rate, 2.092218 seconds, 564800 images
#  8826: 0.055947, 0.038662 avg loss, 0.000100 rate, 2.090887 seconds, 564864 images
# Premature end of JPEG file
#  8827: 0.042873, 0.039083 avg loss, 0.000100 rate, 2.093352 seconds, 564928 images
#  8828: 0.069709, 0.042146 avg loss, 0.000100 rate, 2.105961 seconds, 564992 images
#  8829: 0.040945, 0.042026 avg loss, 0.000100 rate, 2.096973 seconds, 565056 images
#  8830: 0.049402, 0.042763 avg loss, 0.000100 rate, 2.095274 seconds, 565120 images
#  8831: 0.020841, 0.040571 avg loss, 0.000100 rate, 2.795085 seconds, 565184 images
#  8832: 0.034962, 0.040010 avg loss, 0.000100 rate, 2.897466 seconds, 565248 images
#  8833: 0.023716, 0.038381 avg loss, 0.000100 rate, 2.895798 seconds, 565312 images
#  8834: 0.028211, 0.037364 avg loss, 0.000100 rate, 2.900093 seconds, 565376 images
#  8835: 0.021685, 0.035796 avg loss, 0.000100 rate, 2.908985 seconds, 565440 images
#  8836: 0.032525, 0.035469 avg loss, 0.000100 rate, 2.892062 seconds, 565504 images
#  8837: 0.034390, 0.035361 avg loss, 0.000100 rate, 2.885943 seconds, 565568 images
#  8838: 0.043214, 0.036146 avg loss, 0.000100 rate, 2.896241 seconds, 565632 images
# Premature end of JPEG file
#  8839: 0.030135, 0.035545 avg loss, 0.000100 rate, 2.900258 seconds, 565696 images
#  8840: 0.026227, 0.034613 avg loss, 0.000100 rate, 2.900782 seconds, 565760 images
#  8841: 0.047119, 0.035864 avg loss, 0.000100 rate, 2.030687 seconds, 565824 images
#  8842: 0.036863, 0.035964 avg loss, 0.000100 rate, 2.093846 seconds, 565888 images
#  8843: 0.043838, 0.036751 avg loss, 0.000100 rate, 2.103554 seconds, 565952 images
#  8844: 0.024730, 0.035549 avg loss, 0.000100 rate, 2.093136 seconds, 566016 images
# Premature end of JPEG file
#  8845: 0.043424, 0.036337 avg loss, 0.000100 rate, 2.097956 seconds, 566080 images
#  8846: 0.040588, 0.036762 avg loss, 0.000100 rate, 2.113744 seconds, 566144 images
#  8847: 0.046593, 0.037745 avg loss, 0.000100 rate, 2.103927 seconds, 566208 images
#  8848: 0.078387, 0.041809 avg loss, 0.000100 rate, 2.106433 seconds, 566272 images
#  8849: 0.036837, 0.041312 avg loss, 0.000100 rate, 2.085043 seconds, 566336 images
#  8850: 0.015988, 0.038779 avg loss, 0.000100 rate, 2.097937 seconds, 566400 images
#  8851: 0.032727, 0.038174 avg loss, 0.000100 rate, 2.028345 seconds, 566464 images
#  8852: 0.084272, 0.042784 avg loss, 0.000100 rate, 2.095985 seconds, 566528 images
#  8853: 0.036582, 0.042164 avg loss, 0.000100 rate, 2.096011 seconds, 566592 images
#  8854: 0.059843, 0.043932 avg loss, 0.000100 rate, 2.101686 seconds, 566656 images
# Premature end of JPEG file
#  8855: 0.067205, 0.046259 avg loss, 0.000100 rate, 2.102361 seconds, 566720 images
#  8856: 0.073279, 0.048961 avg loss, 0.000100 rate, 2.112410 seconds, 566784 images
#  8857: 0.029457, 0.047011 avg loss, 0.000100 rate, 2.107912 seconds, 566848 images
#  8858: 0.063554, 0.048665 avg loss, 0.000100 rate, 2.105385 seconds, 566912 images
#  8859: 0.051851, 0.048984 avg loss, 0.000100 rate, 2.106281 seconds, 566976 images
#  8860: 0.045802, 0.048665 avg loss, 0.000100 rate, 2.091089 seconds, 567040 images
#  8861: 0.030838, 0.046883 avg loss, 0.000100 rate, 3.306979 seconds, 567104 images
#  8862: 0.074694, 0.049664 avg loss, 0.000100 rate, 3.427587 seconds, 567168 images
#  8863: 0.021146, 0.046812 avg loss, 0.000100 rate, 3.404468 seconds, 567232 images
#  8864: 0.030806, 0.045211 avg loss, 0.000100 rate, 3.430443 seconds, 567296 images
#  8865: 0.050800, 0.045770 avg loss, 0.000100 rate, 3.434743 seconds, 567360 images
#  8866: 0.030777, 0.044271 avg loss, 0.000100 rate, 3.414793 seconds, 567424 images
#  8867: 0.028598, 0.042704 avg loss, 0.000100 rate, 3.421767 seconds, 567488 images
#  8868: 0.044112, 0.042845 avg loss, 0.000100 rate, 3.416371 seconds, 567552 images
#  8869: 0.021799, 0.040740 avg loss, 0.000100 rate, 3.414129 seconds, 567616 images
#  8870: 0.034679, 0.040134 avg loss, 0.000100 rate, 3.409642 seconds, 567680 images
#  8871: 0.036179, 0.039738 avg loss, 0.000100 rate, 2.260429 seconds, 567744 images
#  8872: 0.034384, 0.039203 avg loss, 0.000100 rate, 2.311405 seconds, 567808 images
# Premature end of JPEG file
#  8873: 0.039644, 0.039247 avg loss, 0.000100 rate, 2.317350 seconds, 567872 images
#  8874: 0.045488, 0.039871 avg loss, 0.000100 rate, 2.322822 seconds, 567936 images
#  8875: 0.040564, 0.039940 avg loss, 0.000100 rate, 2.314307 seconds, 568000 images
#  8876: 0.031422, 0.039089 avg loss, 0.000100 rate, 2.313831 seconds, 568064 images
#  8877: 0.055246, 0.040704 avg loss, 0.000100 rate, 2.316072 seconds, 568128 images
#  8878: 0.053702, 0.042004 avg loss, 0.000100 rate, 2.318087 seconds, 568192 images
#  8879: 0.053127, 0.043116 avg loss, 0.000100 rate, 2.321217 seconds, 568256 images
#  8880: 0.074329, 0.046238 avg loss, 0.000100 rate, 2.314867 seconds, 568320 images
# Premature end of JPEG file
#  8881: 0.032506, 0.044864 avg loss, 0.000100 rate, 2.027794 seconds, 568384 images
#  8882: 0.044108, 0.044789 avg loss, 0.000100 rate, 2.091755 seconds, 568448 images
#  8883: 0.039133, 0.044223 avg loss, 0.000100 rate, 2.092916 seconds, 568512 images
#  8884: 0.073760, 0.047177 avg loss, 0.000100 rate, 2.102185 seconds, 568576 images
#  8885: 0.038039, 0.046263 avg loss, 0.000100 rate, 2.109171 seconds, 568640 images
# Premature end of JPEG file
# Premature end of JPEG file
# Premature end of JPEG file
#  8886: 0.074963, 0.049133 avg loss, 0.000100 rate, 2.115207 seconds, 568704 images
#  8887: 0.040473, 0.048267 avg loss, 0.000100 rate, 2.105441 seconds, 568768 images
#  8888: 0.042555, 0.047696 avg loss, 0.000100 rate, 2.092204 seconds, 568832 images
#  8889: 0.036919, 0.046618 avg loss, 0.000100 rate, 2.090817 seconds, 568896 images
#  8890: 0.034791, 0.045435 avg loss, 0.000100 rate, 2.100101 seconds, 568960 images
#  8891: 0.029468, 0.043839 avg loss, 0.000100 rate, 2.602706 seconds, 569024 images
#  8892: 0.021127, 0.041567 avg loss, 0.000100 rate, 2.711774 seconds, 569088 images
#  8893: 0.020289, 0.039440 avg loss, 0.000100 rate, 2.692109 seconds, 569152 images
#  8894: 0.020906, 0.037586 avg loss, 0.000100 rate, 2.706313 seconds, 569216 images
#  8895: 0.025013, 0.036329 avg loss, 0.000100 rate, 2.690946 seconds, 569280 images
# Premature end of JPEG file
#  8896: 0.040996, 0.036796 avg loss, 0.000100 rate, 2.695159 seconds, 569344 images
#  8897: 0.065897, 0.039706 avg loss, 0.000100 rate, 2.687146 seconds, 569408 images
#  8898: 0.015304, 0.037266 avg loss, 0.000100 rate, 2.712973 seconds, 569472 images
# Premature end of JPEG file
#  8899: 0.037250, 0.037264 avg loss, 0.000100 rate, 2.712012 seconds, 569536 images
# Saving weights to /content/app/weights/yolov3_last.weights
# Premature end of JPEG file
#  8900: 0.045054, 0.038043 avg loss, 0.000100 rate, 2.712150 seconds, 569600 images
#  8901: 0.087165, 0.042955 avg loss, 0.000100 rate, 2.618000 seconds, 569664 images
#  8902: 0.044683, 0.043128 avg loss, 0.000100 rate, 2.701428 seconds, 569728 images
#  8903: 0.031802, 0.041996 avg loss, 0.000100 rate, 2.700475 seconds, 569792 images
#  8904: 0.026226, 0.040419 avg loss, 0.000100 rate, 2.701537 seconds, 569856 images
#  8905: 0.033394, 0.039716 avg loss, 0.000100 rate, 2.707088 seconds, 569920 images
#  8906: 0.041557, 0.039900 avg loss, 0.000100 rate, 2.695713 seconds, 569984 images
#  8907: 0.031501, 0.039060 avg loss, 0.000100 rate, 2.693512 seconds, 570048 images
# Premature end of JPEG file
#  8908: 0.050341, 0.040188 avg loss, 0.000100 rate, 2.689711 seconds, 570112 images
#  8909: 0.062476, 0.042417 avg loss, 0.000100 rate, 2.719291 seconds, 570176 images
# Premature end of JPEG file
#  8910: 0.017629, 0.039938 avg loss, 0.000100 rate, 2.685444 seconds, 570240 images
# Premature end of JPEG file
# Premature end of JPEG file
#  8911: 0.069748, 0.042919 avg loss, 0.000100 rate, 4.622814 seconds, 570304 images
# Premature end of JPEG file
#  8912: 0.064489, 0.045076 avg loss, 0.000100 rate, 4.793302 seconds, 570368 images
#  8913: 0.048931, 0.045462 avg loss, 0.000100 rate, 4.741879 seconds, 570432 images
#  8914: 0.034273, 0.044343 avg loss, 0.000100 rate, 4.760136 seconds, 570496 images
#  8915: 0.055222, 0.045431 avg loss, 0.000100 rate, 4.778180 seconds, 570560 images
#  8916: 0.032794, 0.044167 avg loss, 0.000100 rate, 4.763865 seconds, 570624 images
#  8917: 0.039200, 0.043670 avg loss, 0.000100 rate, 4.760716 seconds, 570688 images
#  8918: 0.053310, 0.044634 avg loss, 0.000100 rate, 4.755375 seconds, 570752 images
# Premature end of JPEG file
#  8919: 0.040647, 0.044236 avg loss, 0.000100 rate, 4.792726 seconds, 570816 images
# Premature end of JPEG file
#  8920: 0.036881, 0.043500 avg loss, 0.000100 rate, 4.751572 seconds, 570880 images
#  8921: 0.033069, 0.042457 avg loss, 0.000100 rate, 4.397771 seconds, 570944 images
#  8922: 0.072800, 0.045491 avg loss, 0.000100 rate, 4.529008 seconds, 571008 images
#  8923: 0.051089, 0.046051 avg loss, 0.000100 rate, 4.542200 seconds, 571072 images
#  8924: 0.033571, 0.044803 avg loss, 0.000100 rate, 4.504627 seconds, 571136 images
# Premature end of JPEG file
#  8925: 0.049126, 0.045235 avg loss, 0.000100 rate, 4.524047 seconds, 571200 images
#  8926: 0.029542, 0.043666 avg loss, 0.000100 rate, 4.511898 seconds, 571264 images
# Premature end of JPEG file
#  8927: 0.027824, 0.042082 avg loss, 0.000100 rate, 4.499961 seconds, 571328 images
# Premature end of JPEG file
#  8928: 0.038505, 0.041724 avg loss, 0.000100 rate, 4.517329 seconds, 571392 images
#  8929: 0.050524, 0.042604 avg loss, 0.000100 rate, 4.509743 seconds, 571456 images
#  8930: 0.046119, 0.042956 avg loss, 0.000100 rate, 4.515372 seconds, 571520 images
#  8931: 0.038052, 0.042465 avg loss, 0.000100 rate, 5.162612 seconds, 571584 images
#  8932: 0.041585, 0.042377 avg loss, 0.000100 rate, 5.298216 seconds, 571648 images
# Premature end of JPEG file
# Premature end of JPEG file
#  8933: 0.040685, 0.042208 avg loss, 0.000100 rate, 5.291906 seconds, 571712 images
#  8934: 0.048974, 0.042885 avg loss, 0.000100 rate, 5.286111 seconds, 571776 images
#  8935: 0.061555, 0.044752 avg loss, 0.000100 rate, 5.325218 seconds, 571840 images
#  8936: 0.061348, 0.046411 avg loss, 0.000100 rate, 5.312643 seconds, 571904 images
#  8937: 0.068418, 0.048612 avg loss, 0.000100 rate, 5.311808 seconds, 571968 images
#  8938: 0.059149, 0.049666 avg loss, 0.000100 rate, 5.298635 seconds, 572032 images
#  8939: 0.028567, 0.047556 avg loss, 0.000100 rate, 5.305958 seconds, 572096 images
#  8940: 0.075862, 0.050386 avg loss, 0.000100 rate, 5.291667 seconds, 572160 images
# Premature end of JPEG file
#  8941: 0.039726, 0.049320 avg loss, 0.000100 rate, 4.620793 seconds, 572224 images
#  8942: 0.045867, 0.048975 avg loss, 0.000100 rate, 4.769526 seconds, 572288 images
#  8943: 0.043976, 0.048475 avg loss, 0.000100 rate, 4.762255 seconds, 572352 images
# Premature end of JPEG file
#  8944: 0.031109, 0.046738 avg loss, 0.000100 rate, 4.732655 seconds, 572416 images
# Premature end of JPEG file
#  8945: 0.060310, 0.048096 avg loss, 0.000100 rate, 4.768853 seconds, 572480 images
#  8946: 0.036138, 0.046900 avg loss, 0.000100 rate, 4.744334 seconds, 572544 images
#  8947: 0.036042, 0.045814 avg loss, 0.000100 rate, 4.738007 seconds, 572608 images
# Premature end of JPEG file
#  8948: 0.039495, 0.045182 avg loss, 0.000100 rate, 4.754413 seconds, 572672 images
#  8949: 0.045322, 0.045196 avg loss, 0.000100 rate, 4.779756 seconds, 572736 images
#  8950: 0.043661, 0.045043 avg loss, 0.000100 rate, 4.749259 seconds, 572800 images
#  8951: 0.064270, 0.046965 avg loss, 0.000100 rate, 2.633017 seconds, 572864 images
#  8952: 0.043781, 0.046647 avg loss, 0.000100 rate, 2.719865 seconds, 572928 images
#  8953: 0.054797, 0.047462 avg loss, 0.000100 rate, 2.706204 seconds, 572992 images
#  8954: 0.050364, 0.047752 avg loss, 0.000100 rate, 2.709335 seconds, 573056 images
#  8955: 0.025954, 0.045572 avg loss, 0.000100 rate, 2.688682 seconds, 573120 images
#  8956: 0.020620, 0.043077 avg loss, 0.000100 rate, 2.709011 seconds, 573184 images
#  8957: 0.021627, 0.040932 avg loss, 0.000100 rate, 2.700245 seconds, 573248 images
#  8958: 0.020531, 0.038892 avg loss, 0.000100 rate, 2.698657 seconds, 573312 images
# Premature end of JPEG file
#  8959: 0.069985, 0.042001 avg loss, 0.000100 rate, 2.711404 seconds, 573376 images
#  8960: 0.063192, 0.044121 avg loss, 0.000100 rate, 2.707020 seconds, 573440 images
#  8961: 0.023204, 0.042029 avg loss, 0.000100 rate, 3.305797 seconds, 573504 images
#  8962: 0.025904, 0.040416 avg loss, 0.000100 rate, 3.418295 seconds, 573568 images
#  8963: 0.038568, 0.040232 avg loss, 0.000100 rate, 3.410881 seconds, 573632 images
#  8964: 0.029341, 0.039142 avg loss, 0.000100 rate, 3.414405 seconds, 573696 images
#  8965: 0.039792, 0.039207 avg loss, 0.000100 rate, 3.427152 seconds, 573760 images
#  8966: 0.062888, 0.041575 avg loss, 0.000100 rate, 3.407697 seconds, 573824 images
#  8967: 0.026170, 0.040035 avg loss, 0.000100 rate, 3.397599 seconds, 573888 images
#  8968: 0.034773, 0.039509 avg loss, 0.000100 rate, 3.410292 seconds, 573952 images
# Premature end of JPEG file
#  8969: 0.020940, 0.037652 avg loss, 0.000100 rate, 3.413890 seconds, 574016 images
# Premature end of JPEG file
# Premature end of JPEG file
#  8970: 0.027107, 0.036597 avg loss, 0.000100 rate, 3.403331 seconds, 574080 images
#  8971: 0.042304, 0.037168 avg loss, 0.000100 rate, 3.600373 seconds, 574144 images
# Premature end of JPEG file
#  8972: 0.055698, 0.039021 avg loss, 0.000100 rate, 3.735845 seconds, 574208 images
#  8973: 0.063573, 0.041476 avg loss, 0.000100 rate, 3.733903 seconds, 574272 images
#  8974: 0.027620, 0.040091 avg loss, 0.000100 rate, 3.695234 seconds, 574336 images
#  8975: 0.019975, 0.038079 avg loss, 0.000100 rate, 3.690312 seconds, 574400 images
#  8976: 0.022951, 0.036566 avg loss, 0.000100 rate, 3.700777 seconds, 574464 images
# Premature end of JPEG file
# Premature end of JPEG file
#  8977: 0.020242, 0.034934 avg loss, 0.000100 rate, 3.711264 seconds, 574528 images
#  8978: 0.026796, 0.034120 avg loss, 0.000100 rate, 3.716036 seconds, 574592 images
#  8979: 0.027069, 0.033415 avg loss, 0.000100 rate, 3.702587 seconds, 574656 images
# Premature end of JPEG file
#  8980: 0.031637, 0.033237 avg loss, 0.000100 rate, 3.719400 seconds, 574720 images
#  8981: 0.023789, 0.032292 avg loss, 0.000100 rate, 3.593412 seconds, 574784 images
#  8982: 0.034768, 0.032540 avg loss, 0.000100 rate, 3.761725 seconds, 574848 images
#  8983: 0.032172, 0.032503 avg loss, 0.000100 rate, 3.693899 seconds, 574912 images
#  8984: 0.018917, 0.031144 avg loss, 0.000100 rate, 3.748231 seconds, 574976 images
#  8985: 0.030232, 0.031053 avg loss, 0.000100 rate, 3.723020 seconds, 575040 images
#  8986: 0.040739, 0.032022 avg loss, 0.000100 rate, 3.717214 seconds, 575104 images
#  8987: 0.046010, 0.033421 avg loss, 0.000100 rate, 3.715464 seconds, 575168 images
#  8988: 0.052326, 0.035311 avg loss, 0.000100 rate, 3.694895 seconds, 575232 images
#  8989: 0.054482, 0.037228 avg loss, 0.000100 rate, 3.730693 seconds, 575296 images
# Premature end of JPEG file
#  8990: 0.050288, 0.038534 avg loss, 0.000100 rate, 3.715743 seconds, 575360 images
#  8991: 0.085237, 0.043205 avg loss, 0.000100 rate, 3.595810 seconds, 575424 images
#  8992: 0.046208, 0.043505 avg loss, 0.000100 rate, 3.731525 seconds, 575488 images
#  8993: 0.019548, 0.041109 avg loss, 0.000100 rate, 3.729851 seconds, 575552 images
#  8994: 0.024848, 0.039483 avg loss, 0.000100 rate, 3.700654 seconds, 575616 images
# Premature end of JPEG file
#  8995: 0.025447, 0.038079 avg loss, 0.000100 rate, 3.718727 seconds, 575680 images
#  8996: 0.037907, 0.038062 avg loss, 0.000100 rate, 3.722822 seconds, 575744 images
#  8997: 0.033736, 0.037630 avg loss, 0.000100 rate, 3.709555 seconds, 575808 images
# Premature end of JPEG file
#  8998: 0.035121, 0.037379 avg loss, 0.000100 rate, 3.749067 seconds, 575872 images
#  8999: 0.058852, 0.039526 avg loss, 0.000100 rate, 3.726004 seconds, 575936 images
# Saving weights to /content/app/weights/yolov3_9000.weights
# Saving weights to /content/app/weights/yolov3_last.weights
#  9000: 0.035168, 0.039090 avg loss, 0.000010 rate, 3.727980 seconds, 576000 images
#  9001: 0.036591, 0.038840 avg loss, 0.000010 rate, 4.415422 seconds, 576064 images
#  9002: 0.032752, 0.038231 avg loss, 0.000010 rate, 4.550016 seconds, 576128 images
#  9003: 0.047154, 0.039124 avg loss, 0.000010 rate, 4.527706 seconds, 576192 images
#  9004: 0.050844, 0.040296 avg loss, 0.000010 rate, 4.525391 seconds, 576256 images
# Premature end of JPEG file
#  9005: 0.028691, 0.039135 avg loss, 0.000010 rate, 4.529612 seconds, 576320 images
#  9006: 0.042928, 0.039514 avg loss, 0.000010 rate, 4.562360 seconds, 576384 images
#  9007: 0.028737, 0.038437 avg loss, 0.000010 rate, 4.521044 seconds, 576448 images
# Premature end of JPEG file
#  9008: 0.035295, 0.038123 avg loss, 0.000010 rate, 4.514592 seconds, 576512 images
# Premature end of JPEG file
#  9009: 0.055983, 0.039909 avg loss, 0.000010 rate, 4.519465 seconds, 576576 images
# Premature end of JPEG file
#  9010: 0.031533, 0.039071 avg loss, 0.000010 rate, 4.510394 seconds, 576640 images
#  9011: 0.035714, 0.038735 avg loss, 0.000010 rate, 2.030358 seconds, 576704 images
#  9012: 0.047920, 0.039654 avg loss, 0.000010 rate, 2.093492 seconds, 576768 images
# Premature end of JPEG file
# Premature end of JPEG file
#  9013: 0.030212, 0.038710 avg loss, 0.000010 rate, 2.092700 seconds, 576832 images
#  9014: 0.052829, 0.040122 avg loss, 0.000010 rate, 2.097200 seconds, 576896 images
#  9015: 0.036025, 0.039712 avg loss, 0.000010 rate, 2.097330 seconds, 576960 images
#  9016: 0.059019, 0.041643 avg loss, 0.000010 rate, 2.102460 seconds, 577024 images
#  9017: 0.041131, 0.041592 avg loss, 0.000010 rate, 2.097609 seconds, 577088 images
# Premature end of JPEG file
#  9018: 0.054308, 0.042863 avg loss, 0.000010 rate, 2.093597 seconds, 577152 images
#  9019: 0.035264, 0.042103 avg loss, 0.000010 rate, 2.101772 seconds, 577216 images
# Premature end of JPEG file
#  9020: 0.043329, 0.042226 avg loss, 0.000010 rate, 2.092998 seconds, 577280 images
#  9021: 0.106187, 0.048622 avg loss, 0.000010 rate, 2.027978 seconds, 577344 images
#  9022: 0.102807, 0.054040 avg loss, 0.000010 rate, 2.117734 seconds, 577408 images
#  9023: 0.021849, 0.050821 avg loss, 0.000010 rate, 2.089801 seconds, 577472 images
#  9024: 0.040526, 0.049792 avg loss, 0.000010 rate, 2.099769 seconds, 577536 images
#  9025: 0.025789, 0.047391 avg loss, 0.000010 rate, 2.100408 seconds, 577600 images
#  9026: 0.039377, 0.046590 avg loss, 0.000010 rate, 2.094638 seconds, 577664 images
# Premature end of JPEG file
#  9027: 0.027146, 0.044646 avg loss, 0.000010 rate, 2.096764 seconds, 577728 images
#  9028: 0.049618, 0.045143 avg loss, 0.000010 rate, 2.092163 seconds, 577792 images
# Premature end of JPEG file
# Premature end of JPEG file
#  9029: 0.049314, 0.045560 avg loss, 0.000010 rate, 2.098137 seconds, 577856 images
#  9030: 0.077920, 0.048796 avg loss, 0.000010 rate, 2.105930 seconds, 577920 images
#  9031: 0.059563, 0.049873 avg loss, 0.000010 rate, 4.614565 seconds, 577984 images
# Premature end of JPEG file
#  9032: 0.041218, 0.049007 avg loss, 0.000010 rate, 4.737340 seconds, 578048 images
# Premature end of JPEG file
#  9033: 0.020881, 0.046195 avg loss, 0.000010 rate, 4.736330 seconds, 578112 images
# Premature end of JPEG file
#  9034: 0.038769, 0.045452 avg loss, 0.000010 rate, 4.743945 seconds, 578176 images
#  9035: 0.058611, 0.046768 avg loss, 0.000010 rate, 4.729828 seconds, 578240 images
#  9036: 0.038999, 0.045991 avg loss, 0.000010 rate, 4.753596 seconds, 578304 images
#  9037: 0.042870, 0.045679 avg loss, 0.000010 rate, 4.740260 seconds, 578368 images
#  9038: 0.034929, 0.044604 avg loss, 0.000010 rate, 4.755226 seconds, 578432 images
#  9039: 0.047284, 0.044872 avg loss, 0.000010 rate, 4.752620 seconds, 578496 images
#  9040: 0.072985, 0.047683 avg loss, 0.000010 rate, 4.753960 seconds, 578560 images
#  9041: 0.049352, 0.047850 avg loss, 0.000010 rate, 1.755229 seconds, 578624 images
# Premature end of JPEG file
#  9042: 0.069661, 0.050031 avg loss, 0.000010 rate, 1.802834 seconds, 578688 images
#  9043: 0.074572, 0.052485 avg loss, 0.000010 rate, 1.834052 seconds, 578752 images
#  9044: 0.090351, 0.056272 avg loss, 0.000010 rate, 1.806924 seconds, 578816 images
#  9045: 0.095313, 0.060176 avg loss, 0.000010 rate, 1.806992 seconds, 578880 images
# Premature end of JPEG file
#  9046: 0.076895, 0.061848 avg loss, 0.000010 rate, 1.808165 seconds, 578944 images
#  9047: 0.054203, 0.061083 avg loss, 0.000010 rate, 1.807881 seconds, 579008 images
# Premature end of JPEG file
# Premature end of JPEG file
#  9048: 0.058032, 0.060778 avg loss, 0.000010 rate, 1.804732 seconds, 579072 images
#  9049: 0.083118, 0.063012 avg loss, 0.000010 rate, 1.805291 seconds, 579136 images
#  9050: 0.068820, 0.063593 avg loss, 0.000010 rate, 1.820107 seconds, 579200 images
#  9051: 0.035142, 0.060748 avg loss, 0.000010 rate, 3.309580 seconds, 579264 images
#  9052: 0.035074, 0.058181 avg loss, 0.000010 rate, 3.417452 seconds, 579328 images
#  9053: 0.024361, 0.054799 avg loss, 0.000010 rate, 3.404825 seconds, 579392 images
#  9054: 0.024920, 0.051811 avg loss, 0.000010 rate, 3.442290 seconds, 579456 images
#  9055: 0.021312, 0.048761 avg loss, 0.000010 rate, 3.407453 seconds, 579520 images
#  9056: 0.036810, 0.047566 avg loss, 0.000010 rate, 3.401620 seconds, 579584 images
#  9057: 0.023909, 0.045200 avg loss, 0.000010 rate, 3.396050 seconds, 579648 images
#  9058: 0.037065, 0.044387 avg loss, 0.000010 rate, 3.404861 seconds, 579712 images
#  9059: 0.062264, 0.046174 avg loss, 0.000010 rate, 3.433268 seconds, 579776 images
#  9060: 0.047293, 0.046286 avg loss, 0.000010 rate, 3.420041 seconds, 579840 images
# Premature end of JPEG file
# ...
#  9825: 0.036873, 0.039158 avg loss, 0.000010 rate, 2.708524 seconds, 628800 images
#  9826: 0.056623, 0.040905 avg loss, 0.000010 rate, 2.699738 seconds, 628864 images
#  9827: 0.025927, 0.039407 avg loss, 0.000010 rate, 2.707021 seconds, 628928 images
#  9828: 0.025345, 0.038001 avg loss, 0.000010 rate, 2.691948 seconds, 628992 images
# Premature end of JPEG file
#  9829: 0.057807, 0.039981 avg loss, 0.000010 rate, 2.696219 seconds, 629056 images
# Premature end of JPEG file
#  9830: 0.019127, 0.037896 avg loss, 0.000010 rate, 2.685630 seconds, 629120 images
#  9831: 0.025198, 0.036626 avg loss, 0.000010 rate, 2.791195 seconds, 629184 images
#  9832: 0.017741, 0.034738 avg loss, 0.000010 rate, 2.873835 seconds, 629248 images
#  9833: 0.021609, 0.033425 avg loss, 0.000010 rate, 2.881913 seconds, 629312 images
#  9834: 0.021377, 0.032220 avg loss, 0.000010 rate, 2.890533 seconds, 629376 images
#  9835: 0.029827, 0.031981 avg loss, 0.000010 rate, 2.887644 seconds, 629440 images
# Premature end of JPEG file
#  9836: 0.027337, 0.031516 avg loss, 0.000010 rate, 2.900160 seconds, 629504 images
#  9837: 0.033941, 0.031759 avg loss, 0.000010 rate, 2.891731 seconds, 629568 images
#  9838: 0.027674, 0.031350 avg loss, 0.000010 rate, 2.885036 seconds, 629632 images
#  9839: 0.018851, 0.030100 avg loss, 0.000010 rate, 2.886625 seconds, 629696 images
#  9840: 0.020813, 0.029172 avg loss, 0.000010 rate, 2.878724 seconds, 629760 images
#  9841: 0.068002, 0.033055 avg loss, 0.000010 rate, 2.028274 seconds, 629824 images
# Premature end of JPEG file
# Premature end of JPEG file
#  9842: 0.058935, 0.035643 avg loss, 0.000010 rate, 2.090157 seconds, 629888 images
#  9843: 0.076142, 0.039693 avg loss, 0.000010 rate, 2.088707 seconds, 629952 images
# Premature end of JPEG file
#  9844: 0.038101, 0.039533 avg loss, 0.000010 rate, 2.108116 seconds, 630016 images
# Premature end of JPEG file
#  9845: 0.041850, 0.039765 avg loss, 0.000010 rate, 2.088859 seconds, 630080 images
#  9846: 0.038686, 0.039657 avg loss, 0.000010 rate, 2.084537 seconds, 630144 images
#  9847: 0.042948, 0.039986 avg loss, 0.000010 rate, 2.089226 seconds, 630208 images
# Premature end of JPEG file
# Premature end of JPEG file
#  9848: 0.057849, 0.041773 avg loss, 0.000010 rate, 2.087362 seconds, 630272 images
#  9849: 0.036881, 0.041283 avg loss, 0.000010 rate, 2.089219 seconds, 630336 images
#  9850: 0.035978, 0.040753 avg loss, 0.000010 rate, 2.096847 seconds, 630400 images
#  9851: 0.055639, 0.042242 avg loss, 0.000010 rate, 2.605542 seconds, 630464 images
#  9852: 0.021806, 0.040198 avg loss, 0.000010 rate, 2.709714 seconds, 630528 images
# Premature end of JPEG file
#  9853: 0.031364, 0.039315 avg loss, 0.000010 rate, 2.679873 seconds, 630592 images
#  9854: 0.034200, 0.038803 avg loss, 0.000010 rate, 2.691745 seconds, 630656 images
#  9855: 0.030548, 0.037978 avg loss, 0.000010 rate, 2.696744 seconds, 630720 images
#  9856: 0.032114, 0.037391 avg loss, 0.000010 rate, 2.683284 seconds, 630784 images
#  9857: 0.026745, 0.036327 avg loss, 0.000010 rate, 2.702955 seconds, 630848 images
#  9858: 0.054354, 0.038129 avg loss, 0.000010 rate, 2.687328 seconds, 630912 images
# Premature end of JPEG file
#  9859: 0.020208, 0.036337 avg loss, 0.000010 rate, 2.683436 seconds, 630976 images
#  9860: 0.027818, 0.035485 avg loss, 0.000010 rate, 2.697008 seconds, 631040 images
#  9861: 0.028164, 0.034753 avg loss, 0.000010 rate, 2.035849 seconds, 631104 images
#  9862: 0.041889, 0.035467 avg loss, 0.000010 rate, 2.089696 seconds, 631168 images
#  9863: 0.034936, 0.035414 avg loss, 0.000010 rate, 2.086648 seconds, 631232 images
#  9864: 0.047251, 0.036597 avg loss, 0.000010 rate, 2.098474 seconds, 631296 images
# Premature end of JPEG file
#  9865: 0.049802, 0.037918 avg loss, 0.000010 rate, 2.095086 seconds, 631360 images
#  9866: 0.030354, 0.037161 avg loss, 0.000010 rate, 2.083435 seconds, 631424 images
#  9867: 0.058698, 0.039315 avg loss, 0.000010 rate, 2.088470 seconds, 631488 images
#  9868: 0.032566, 0.038640 avg loss, 0.000010 rate, 2.096735 seconds, 631552 images
#  9869: 0.029612, 0.037737 avg loss, 0.000010 rate, 2.098578 seconds, 631616 images
#  9870: 0.046825, 0.038646 avg loss, 0.000010 rate, 2.087306 seconds, 631680 images
#  9871: 0.034149, 0.038196 avg loss, 0.000010 rate, 5.147180 seconds, 631744 images
#  9872: 0.033450, 0.037722 avg loss, 0.000010 rate, 5.314162 seconds, 631808 images
# Premature end of JPEG file
# Premature end of JPEG file
#  9873: 0.058606, 0.039810 avg loss, 0.000010 rate, 5.288642 seconds, 631872 images
#  9874: 0.041598, 0.039989 avg loss, 0.000010 rate, 5.284788 seconds, 631936 images
#  9875: 0.046926, 0.040683 avg loss, 0.000010 rate, 5.310624 seconds, 632000 images
#  9876: 0.050816, 0.041696 avg loss, 0.000010 rate, 5.292701 seconds, 632064 images
#  9877: 0.043306, 0.041857 avg loss, 0.000010 rate, 5.275464 seconds, 632128 images
#  9878: 0.045070, 0.042178 avg loss, 0.000010 rate, 5.271699 seconds, 632192 images
#  9879: 0.032284, 0.041189 avg loss, 0.000010 rate, 5.296472 seconds, 632256 images
# Premature end of JPEG file
# Premature end of JPEG file
#  9880: 0.044965, 0.041567 avg loss, 0.000010 rate, 5.282683 seconds, 632320 images
#  9881: 0.043151, 0.041725 avg loss, 0.000010 rate, 2.235744 seconds, 632384 images
#  9882: 0.030127, 0.040565 avg loss, 0.000010 rate, 2.303076 seconds, 632448 images
#  9883: 0.045880, 0.041097 avg loss, 0.000010 rate, 2.313841 seconds, 632512 images
# Premature end of JPEG file
#  9884: 0.034463, 0.040433 avg loss, 0.000010 rate, 2.309330 seconds, 632576 images
#  9885: 0.041687, 0.040559 avg loss, 0.000010 rate, 2.315038 seconds, 632640 images
#  9886: 0.042601, 0.040763 avg loss, 0.000010 rate, 2.313662 seconds, 632704 images
#  9887: 0.036715, 0.040358 avg loss, 0.000010 rate, 2.317640 seconds, 632768 images
#  9888: 0.055946, 0.041917 avg loss, 0.000010 rate, 2.321534 seconds, 632832 images
#  9889: 0.074992, 0.045225 avg loss, 0.000010 rate, 2.324767 seconds, 632896 images
#  9890: 0.044354, 0.045138 avg loss, 0.000010 rate, 2.309477 seconds, 632960 images
#  9891: 0.020743, 0.042698 avg loss, 0.000010 rate, 2.794888 seconds, 633024 images
# Premature end of JPEG file
#  9892: 0.026913, 0.041119 avg loss, 0.000010 rate, 2.887592 seconds, 633088 images
#  9893: 0.035508, 0.040558 avg loss, 0.000010 rate, 2.903634 seconds, 633152 images
#  9894: 0.037578, 0.040260 avg loss, 0.000010 rate, 2.901213 seconds, 633216 images
#  9895: 0.021545, 0.038389 avg loss, 0.000010 rate, 2.886282 seconds, 633280 images
#  9896: 0.055535, 0.040103 avg loss, 0.000010 rate, 2.895314 seconds, 633344 images
#  9897: 0.025855, 0.038678 avg loss, 0.000010 rate, 2.898699 seconds, 633408 images
#  9898: 0.036275, 0.038438 avg loss, 0.000010 rate, 2.921765 seconds, 633472 images
#  9899: 0.015416, 0.036136 avg loss, 0.000010 rate, 2.903912 seconds, 633536 images
# Saving weights to /content/app/weights/yolov3_last.weights
#  9900: 0.025302, 0.035053 avg loss, 0.000010 rate, 2.870797 seconds, 633600 images
#  9901: 0.021522, 0.033699 avg loss, 0.000010 rate, 2.619619 seconds, 633664 images
#  9902: 0.035342, 0.033864 avg loss, 0.000010 rate, 2.699808 seconds, 633728 images
#  9903: 0.031672, 0.033645 avg loss, 0.000010 rate, 2.704025 seconds, 633792 images
#  9904: 0.026047, 0.032885 avg loss, 0.000010 rate, 2.713424 seconds, 633856 images
#  9905: 0.027158, 0.032312 avg loss, 0.000010 rate, 2.720137 seconds, 633920 images
# Premature end of JPEG file
# Premature end of JPEG file
#  9906: 0.034049, 0.032486 avg loss, 0.000010 rate, 2.718929 seconds, 633984 images
#  9907: 0.018441, 0.031081 avg loss, 0.000010 rate, 2.702266 seconds, 634048 images
#  9908: 0.054498, 0.033423 avg loss, 0.000010 rate, 2.716695 seconds, 634112 images
#  9909: 0.024722, 0.032553 avg loss, 0.000010 rate, 2.699624 seconds, 634176 images
#  9910: 0.029932, 0.032291 avg loss, 0.000010 rate, 2.704216 seconds, 634240 images
#  9911: 0.046512, 0.033713 avg loss, 0.000010 rate, 4.639483 seconds, 634304 images
#  9912: 0.035230, 0.033865 avg loss, 0.000010 rate, 4.778990 seconds, 634368 images
#  9913: 0.061677, 0.036646 avg loss, 0.000010 rate, 4.753427 seconds, 634432 images
#  9914: 0.042089, 0.037190 avg loss, 0.000010 rate, 4.777941 seconds, 634496 images
#  9915: 0.032760, 0.036747 avg loss, 0.000010 rate, 4.765215 seconds, 634560 images
#  9916: 0.037789, 0.036851 avg loss, 0.000010 rate, 4.778640 seconds, 634624 images
#  9917: 0.025111, 0.035677 avg loss, 0.000010 rate, 4.754689 seconds, 634688 images
#  9918: 0.036574, 0.035767 avg loss, 0.000010 rate, 4.787672 seconds, 634752 images
#  9919: 0.041814, 0.036372 avg loss, 0.000010 rate, 4.757343 seconds, 634816 images
#  9920: 0.049704, 0.037705 avg loss, 0.000010 rate, 4.747168 seconds, 634880 images
#  9921: 0.032547, 0.037189 avg loss, 0.000010 rate, 2.629211 seconds, 634944 images
#  9922: 0.021308, 0.035601 avg loss, 0.000010 rate, 2.711767 seconds, 635008 images
#  9923: 0.031246, 0.035166 avg loss, 0.000010 rate, 2.698848 seconds, 635072 images
#  9924: 0.014795, 0.033128 avg loss, 0.000010 rate, 2.694511 seconds, 635136 images
#  9925: 0.057882, 0.035604 avg loss, 0.000010 rate, 2.701224 seconds, 635200 images
#  9926: 0.058613, 0.037905 avg loss, 0.000010 rate, 2.706981 seconds, 635264 images
#  9927: 0.032927, 0.037407 avg loss, 0.000010 rate, 2.708225 seconds, 635328 images
#  9928: 0.029693, 0.036635 avg loss, 0.000010 rate, 2.698763 seconds, 635392 images
# Premature end of JPEG file
#  9929: 0.044390, 0.037411 avg loss, 0.000010 rate, 2.700965 seconds, 635456 images
#  9930: 0.048746, 0.038544 avg loss, 0.000010 rate, 2.699651 seconds, 635520 images
#  9931: 0.032528, 0.037943 avg loss, 0.000010 rate, 2.031478 seconds, 635584 images
# Premature end of JPEG file
#  9932: 0.033328, 0.037481 avg loss, 0.000010 rate, 2.106684 seconds, 635648 images
#  9933: 0.042971, 0.038030 avg loss, 0.000010 rate, 2.095704 seconds, 635712 images
#  9934: 0.030553, 0.037283 avg loss, 0.000010 rate, 2.095537 seconds, 635776 images
#  9935: 0.036513, 0.037206 avg loss, 0.000010 rate, 2.097626 seconds, 635840 images
# Premature end of JPEG file
#  9936: 0.022900, 0.035775 avg loss, 0.000010 rate, 2.099974 seconds, 635904 images
#  9937: 0.049201, 0.037118 avg loss, 0.000010 rate, 2.101452 seconds, 635968 images
#  9938: 0.037619, 0.037168 avg loss, 0.000010 rate, 2.099128 seconds, 636032 images
#  9939: 0.034966, 0.036947 avg loss, 0.000010 rate, 2.091345 seconds, 636096 images
# Premature end of JPEG file
#  9940: 0.072378, 0.040491 avg loss, 0.000010 rate, 2.095119 seconds, 636160 images
# Premature end of JPEG file
#  9941: 0.038307, 0.040272 avg loss, 0.000010 rate, 2.029816 seconds, 636224 images
#  9942: 0.037539, 0.039999 avg loss, 0.000010 rate, 2.101989 seconds, 636288 images
# Premature end of JPEG file
#  9943: 0.041595, 0.040158 avg loss, 0.000010 rate, 2.098809 seconds, 636352 images
#  9944: 0.030666, 0.039209 avg loss, 0.000010 rate, 2.097574 seconds, 636416 images
# Premature end of JPEG file
#  9945: 0.038948, 0.039183 avg loss, 0.000010 rate, 2.098237 seconds, 636480 images
#  9946: 0.049577, 0.040223 avg loss, 0.000010 rate, 2.109494 seconds, 636544 images
#  9947: 0.038766, 0.040077 avg loss, 0.000010 rate, 2.102421 seconds, 636608 images
#  9948: 0.072964, 0.043366 avg loss, 0.000010 rate, 2.088772 seconds, 636672 images
#  9949: 0.063350, 0.045364 avg loss, 0.000010 rate, 2.100088 seconds, 636736 images
# Premature end of JPEG file
#  9950: 0.025864, 0.043414 avg loss, 0.000010 rate, 2.108815 seconds, 636800 images
#  9951: 0.031031, 0.042176 avg loss, 0.000010 rate, 4.430762 seconds, 636864 images
#  9952: 0.033109, 0.041269 avg loss, 0.000010 rate, 4.502932 seconds, 636928 images
#  9953: 0.038093, 0.040951 avg loss, 0.000010 rate, 4.513673 seconds, 636992 images
#  9954: 0.035384, 0.040395 avg loss, 0.000010 rate, 4.523677 seconds, 637056 images
#  9955: 0.040543, 0.040410 avg loss, 0.000010 rate, 4.492771 seconds, 637120 images
#  9956: 0.044062, 0.040775 avg loss, 0.000010 rate, 4.501757 seconds, 637184 images
#  9957: 0.049596, 0.041657 avg loss, 0.000010 rate, 4.503798 seconds, 637248 images
#  9958: 0.022295, 0.039721 avg loss, 0.000010 rate, 4.504442 seconds, 637312 images
#  9959: 0.027992, 0.038548 avg loss, 0.000010 rate, 4.521177 seconds, 637376 images
#  9960: 0.047359, 0.039429 avg loss, 0.000010 rate, 4.533339 seconds, 637440 images
#  9961: 0.020538, 0.037540 avg loss, 0.000010 rate, 4.378531 seconds, 637504 images
#  9962: 0.039165, 0.037702 avg loss, 0.000010 rate, 4.503837 seconds, 637568 images
#  9963: 0.030173, 0.036949 avg loss, 0.000010 rate, 4.510034 seconds, 637632 images
#  9964: 0.027591, 0.036014 avg loss, 0.000010 rate, 4.514420 seconds, 637696 images
#  9965: 0.023137, 0.034726 avg loss, 0.000010 rate, 4.518478 seconds, 637760 images
# Premature end of JPEG file
# Premature end of JPEG file
# Premature end of JPEG file
#  9966: 0.046900, 0.035943 avg loss, 0.000010 rate, 4.531754 seconds, 637824 images
#  9967: 0.046231, 0.036972 avg loss, 0.000010 rate, 4.517280 seconds, 637888 images
#  9968: 0.054396, 0.038715 avg loss, 0.000010 rate, 4.508271 seconds, 637952 images
#  9969: 0.035076, 0.038351 avg loss, 0.000010 rate, 4.511847 seconds, 638016 images
#  9970: 0.044894, 0.039005 avg loss, 0.000010 rate, 4.510918 seconds, 638080 images
# Premature end of JPEG file
#  9971: 0.072734, 0.042378 avg loss, 0.000010 rate, 2.605274 seconds, 638144 images
#  9972: 0.026054, 0.040746 avg loss, 0.000010 rate, 2.689072 seconds, 638208 images
#  9973: 0.036554, 0.040326 avg loss, 0.000010 rate, 2.703283 seconds, 638272 images
#  9974: 0.037555, 0.040049 avg loss, 0.000010 rate, 2.696627 seconds, 638336 images
#  9975: 0.033472, 0.039392 avg loss, 0.000010 rate, 2.693644 seconds, 638400 images
#  9976: 0.034396, 0.038892 avg loss, 0.000010 rate, 2.704561 seconds, 638464 images
#  9977: 0.029889, 0.037992 avg loss, 0.000010 rate, 2.692731 seconds, 638528 images
# Premature end of JPEG file
#  9978: 0.033934, 0.037586 avg loss, 0.000010 rate, 2.691487 seconds, 638592 images
# Premature end of JPEG file
#  9979: 0.035080, 0.037335 avg loss, 0.000010 rate, 2.709608 seconds, 638656 images
#  9980: 0.037139, 0.037316 avg loss, 0.000010 rate, 2.705293 seconds, 638720 images
# Premature end of JPEG file
#  9981: 0.048986, 0.038483 avg loss, 0.000010 rate, 2.240955 seconds, 638784 images
#  9982: 0.058370, 0.040471 avg loss, 0.000010 rate, 2.326134 seconds, 638848 images
#  9983: 0.055090, 0.041933 avg loss, 0.000010 rate, 2.316269 seconds, 638912 images
#  9984: 0.024575, 0.040197 avg loss, 0.000010 rate, 2.312608 seconds, 638976 images
#  9985: 0.042449, 0.040423 avg loss, 0.000010 rate, 2.309310 seconds, 639040 images
#  9986: 0.025336, 0.038914 avg loss, 0.000010 rate, 2.318302 seconds, 639104 images
#  9987: 0.028451, 0.037868 avg loss, 0.000010 rate, 2.310323 seconds, 639168 images
#  9988: 0.034623, 0.037543 avg loss, 0.000010 rate, 2.313180 seconds, 639232 images
# Premature end of JPEG file
#  9989: 0.023122, 0.036101 avg loss, 0.000010 rate, 2.309604 seconds, 639296 images
#  9990: 0.028137, 0.035305 avg loss, 0.000010 rate, 2.317060 seconds, 639360 images
# Premature end of JPEG file
#  9991: 0.047629, 0.036537 avg loss, 0.000010 rate, 2.618511 seconds, 639424 images
#  9992: 0.034845, 0.036368 avg loss, 0.000010 rate, 2.704708 seconds, 639488 images
# Premature end of JPEG file
#  9993: 0.037418, 0.036473 avg loss, 0.000010 rate, 2.683386 seconds, 639552 images
#  9994: 0.024162, 0.035242 avg loss, 0.000010 rate, 2.697592 seconds, 639616 images
#  9995: 0.028262, 0.034544 avg loss, 0.000010 rate, 2.689447 seconds, 639680 images
#  9996: 0.037117, 0.034801 avg loss, 0.000010 rate, 2.706137 seconds, 639744 images
#  9997: 0.025890, 0.033910 avg loss, 0.000010 rate, 2.690965 seconds, 639808 images
# Premature end of JPEG file
# Premature end of JPEG file
#  9998: 0.039443, 0.034463 avg loss, 0.000010 rate, 2.704234 seconds, 639872 images
# Premature end of JPEG file
#  9999: 0.029781, 0.033995 avg loss, 0.000010 rate, 2.719323 seconds, 639936 images
# Saving weights to /content/app/weights/yolov3_10000.weights
# Saving weights to /content/app/weights/yolov3_last.weights
# Saving weights to /content/app/weights/yolov3_final.weights
#  10000: 0.033748, 0.033970 avg loss, 0.000010 rate, 2.606945 seconds, 640000 images

# %% [markdown]
# # 檢視訓練成果
#
# 檢測圖片時，我們只需要 `obj.names`, `yolov3.cfg` 以及 weights 檔就夠。我們可以直接利用 Opencv 內建的 darknet 來讀取網路並產生出預測。

# %%
GITHUB_CODEBASE_DIR_PATH = "/drive/My Drive/Final_Project/train_yolo_with_custom_dataset_on_colab_101"

# %%
TO_DETECTING_IMAGE_DIR_PATH = GITHUB_CODEBASE_DIR_PATH+"/to_detect_images"

# Use python to read 

import os
import cv2
import numpy as np
import glob
from google.colab.patches import cv2_imshow

import pprint
pp = pprint.PrettyPrinter(indent=4)


def detecting_one_image(net, output_layers, img):
  # Detecting objects
  # cv::dnn::blobFromImage (InputArray image, double scalefactor=1.0, const Size &size=Size(), const Scalar &mean=Scalar(), bool swapRB=false, bool crop=false, int ddepth=CV_32F)
  blob = cv2.dnn.blobFromImage(img, 0.00392, (416, 416), (0, 0, 0), True, crop=False)
  net.setInput(blob)
  outs = net.forward(output_layers)

  return outs

# Load Yolo
net = cv2.dnn.readNet(GDRIVE_WEIGHTS_DIR_PATH+"/yolov3_last.weights", GDRIVE_CFG_DIR_PATH+"/yolov3.cfg")
layer_names = net.getLayerNames()
output_layers = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]

# Load label names
with open(GDRIVE_CFG_DIR_PATH+"/obj.names", "r") as f:
  classes = [line.strip() for line in f.readlines()]

# Generate display colors
colors = np.random.uniform(0, 255, size=(len(classes), 3))

for fpath in glob.glob(os.path.join(TO_DETECTING_IMAGE_DIR_PATH, "*.jpg")):
  print("fpath", fpath)

  # Loading image
  img = cv2.imread(fpath)
  height, width, channels = img.shape

  if width>800: # resize for display purpose
    dim = (800, int(800*height/width))
    img = cv2.resize(img, dim, interpolation=cv2.INTER_AREA)
    height, width, channels = img.shape

  outs = detecting_one_image(net, output_layers, img)

  # Showing informations on the screen
  for out in outs:
    for detection in out:
      scores = detection[5:]
      class_id = np.argmax(scores)
      confidence = scores[class_id]
      if confidence > 0.3:
        # Object detected
        center_x = int(detection[0] * width)
        center_y = int(detection[1] * height)
        w = int(detection[2] * width)
        h = int(detection[3] * height)

        # Rectangle coordinates
        x = int(center_x - w / 2)
        y = int(center_y - h / 2)

        label = "(%.2f) %s" % (confidence, classes[class_id])

        cv2.rectangle(img, (x, y), (x + w, y + h), colors[class_id], 2)
        cv2.putText(img, label, (x, y+h-5), cv2.FONT_HERSHEY_PLAIN, 1, colors[class_id], 1)

  cv2_imshow(img)

# %% [markdown]
# # **跑影片**

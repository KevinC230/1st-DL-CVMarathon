# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
import tensorflow as tf
print(tf.__version__)

import os
from google.colab import drive 
drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4")
# %cd cupoy_cv_part4
# Out:
# `%tensorflow_version` only switches the major version: `1.x` or `2.x`.
# You set: `1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2`. This will be interpreted as: `1.x`.
#
#
# TensorFlow is already loaded. Please restart the runtime to change versions.
# 1.15.0
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# [Errno 2] No such file or directory: 'gdrive/My Drive'
# /content/gdrive/My Drive/cupoy_cv_part4
# [Errno 2] No such file or directory: 'cupoy_cv_part4'
# /content/gdrive/My Drive/cupoy_cv_part4

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
# checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
checkpoint = ModelCheckpoint('weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=1, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/1
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0019 - val_loss: 0.0019
#
# Epoch 00001: val_loss improved from 0.00240 to 0.00186, saving model to weights.h5

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
imgs_test.shape
# Out:
# (1783, 96, 96)

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code

imgs_train_f = imgs_train[::-1,:,:]
points_train_f = points_train[::-1,:]
# training the model
hist_model = model.fit(imgs_train_f.reshape(-1, 96, 96, 1), 
                       points_train_f, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0016 - val_loss: 8.8758e-04
#
# Epoch 00001: val_loss improved from 0.00103 to 0.00089, saving model to weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0015 - val_loss: 8.8424e-04
#
# Epoch 00002: val_loss improved from 0.00089 to 0.00088, saving model to weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0014 - val_loss: 8.7582e-04
#
# Epoch 00003: val_loss improved from 0.00088 to 0.00088, saving model to weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0014 - val_loss: 9.0919e-04
#
# Epoch 00004: val_loss did not improve from 0.00088
# Epoch 5/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0014 - val_loss: 9.3393e-04
#
# Epoch 00005: val_loss did not improve from 0.00088
# Epoch 6/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0014 - val_loss: 8.9516e-04
#
# Epoch 00006: val_loss did not improve from 0.00088
# Epoch 7/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0013 - val_loss: 8.6127e-04
#
# Epoch 00007: val_loss improved from 0.00088 to 0.00086, saving model to weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0013 - val_loss: 8.6495e-04
#
# Epoch 00008: val_loss did not improve from 0.00086
# Epoch 9/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0013 - val_loss: 8.4750e-04
#
# Epoch 00009: val_loss improved from 0.00086 to 0.00085, saving model to weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0013 - val_loss: 8.5725e-04
#
# Epoch 00010: val_loss did not improve from 0.00085
# Epoch 11/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0013 - val_loss: 8.6659e-04
#
# Epoch 00011: val_loss did not improve from 0.00085
# Epoch 12/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0012 - val_loss: 8.4619e-04
#
# Epoch 00012: val_loss improved from 0.00085 to 0.00085, saving model to weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0012 - val_loss: 8.3613e-04
#
# Epoch 00013: val_loss improved from 0.00085 to 0.00084, saving model to weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0012 - val_loss: 8.5639e-04
#
# Epoch 00014: val_loss did not improve from 0.00084
# Epoch 15/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0012 - val_loss: 8.1607e-04
#
# Epoch 00015: val_loss improved from 0.00084 to 0.00082, saving model to weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0012 - val_loss: 8.4050e-04
#
# Epoch 00016: val_loss did not improve from 0.00082
# Epoch 17/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0012 - val_loss: 8.2597e-04
#
# Epoch 00017: val_loss did not improve from 0.00082
# Epoch 18/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0012 - val_loss: 8.5549e-04
#
# Epoch 00018: val_loss did not improve from 0.00082
# Epoch 19/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0012 - val_loss: 8.4002e-04
#
# Epoch 00019: val_loss did not improve from 0.00082
# Epoch 20/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0012 - val_loss: 8.6597e-04
#
# Epoch 00020: val_loss did not improve from 0.00082
# Epoch 21/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0012 - val_loss: 8.5686e-04
#
# Epoch 00021: val_loss did not improve from 0.00082
# Epoch 22/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0012 - val_loss: 8.5460e-04
#
# Epoch 00022: val_loss did not improve from 0.00082
# Epoch 23/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0011 - val_loss: 8.9285e-04
#
# Epoch 00023: val_loss did not improve from 0.00082
# Epoch 24/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0011 - val_loss: 8.8609e-04
#
# Epoch 00024: val_loss did not improve from 0.00082
# Epoch 25/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0011 - val_loss: 8.8889e-04
#
# Epoch 00025: val_loss did not improve from 0.00082
# Epoch 26/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0011 - val_loss: 8.9324e-04
#
# Epoch 00026: val_loss did not improve from 0.00082
# Epoch 27/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0011 - val_loss: 9.2149e-04
#
# Epoch 00027: val_loss did not improve from 0.00082
# Epoch 28/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0011 - val_loss: 9.2793e-04
#
# Epoch 00028: val_loss did not improve from 0.00082
# Epoch 29/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0011 - val_loss: 9.3062e-04
#
# Epoch 00029: val_loss did not improve from 0.00082
# Epoch 30/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0011 - val_loss: 9.0099e-04
#
# Epoch 00030: val_loss did not improve from 0.00082
# Epoch 31/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0011 - val_loss: 9.2854e-04
#
# Epoch 00031: val_loss did not improve from 0.00082
# Epoch 32/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0011 - val_loss: 9.4305e-04
#
# Epoch 00032: val_loss did not improve from 0.00082
# Epoch 33/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0010 - val_loss: 9.3140e-04
#
# Epoch 00033: val_loss did not improve from 0.00082
# Epoch 34/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0010 - val_loss: 9.3313e-04
#
# Epoch 00034: val_loss did not improve from 0.00082
# Epoch 35/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 0.0010 - val_loss: 9.3370e-04
#
# Epoch 00035: val_loss did not improve from 0.00082
# Epoch 36/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0010 - val_loss: 9.6027e-04
#
# Epoch 00036: val_loss did not improve from 0.00082
# Epoch 37/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.9114e-04 - val_loss: 9.3662e-04
#
# Epoch 00037: val_loss did not improve from 0.00082
# Epoch 38/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.8872e-04 - val_loss: 0.0010
#
# Epoch 00038: val_loss did not improve from 0.00082
# Epoch 39/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.6266e-04 - val_loss: 9.6753e-04
#
# Epoch 00039: val_loss did not improve from 0.00082
# Epoch 40/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.4640e-04 - val_loss: 9.8086e-04
#
# Epoch 00040: val_loss did not improve from 0.00082
# Epoch 41/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.2060e-04 - val_loss: 9.9622e-04
#
# Epoch 00041: val_loss did not improve from 0.00082
# Epoch 42/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.1646e-04 - val_loss: 0.0010
#
# Epoch 00042: val_loss did not improve from 0.00082
# Epoch 43/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.0510e-04 - val_loss: 9.7148e-04
#
# Epoch 00043: val_loss did not improve from 0.00082
# Epoch 44/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.8665e-04 - val_loss: 0.0010
#
# Epoch 00044: val_loss did not improve from 0.00082
# Epoch 45/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.7966e-04 - val_loss: 0.0010
#
# Epoch 00045: val_loss did not improve from 0.00082
# Epoch 46/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.5141e-04 - val_loss: 0.0011
#
# Epoch 00046: val_loss did not improve from 0.00082
# Epoch 47/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.4611e-04 - val_loss: 0.0010
#
# Epoch 00047: val_loss did not improve from 0.00082
# Epoch 48/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.1056e-04 - val_loss: 0.0011
#
# Epoch 00048: val_loss did not improve from 0.00082
# Epoch 49/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.0066e-04 - val_loss: 0.0010
#
# Epoch 00049: val_loss did not improve from 0.00082
# Epoch 50/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 7.8001e-04 - val_loss: 9.9337e-04
#
# Epoch 00050: val_loss did not improve from 0.00082
# Epoch 51/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 7.7428e-04 - val_loss: 0.0010
#
# Epoch 00051: val_loss did not improve from 0.00082
# Epoch 52/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 7.7236e-04 - val_loss: 0.0011
#
# Epoch 00052: val_loss did not improve from 0.00082
# Epoch 53/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 7.4987e-04 - val_loss: 0.0010
#
# Epoch 00053: val_loss did not improve from 0.00082
# Epoch 54/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 7.3779e-04 - val_loss: 0.0010
#
# Epoch 00054: val_loss did not improve from 0.00082
# Epoch 55/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 7.0766e-04 - val_loss: 0.0010
#
# Epoch 00055: val_loss did not improve from 0.00082
# Epoch 56/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 6.9885e-04 - val_loss: 0.0011
#
# Epoch 00056: val_loss did not improve from 0.00082
# Epoch 57/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 6.6948e-04 - val_loss: 0.0011
#
# Epoch 00057: val_loss did not improve from 0.00082
# Epoch 58/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 6.6188e-04 - val_loss: 0.0011
#
# Epoch 00058: val_loss did not improve from 0.00082
# Epoch 59/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 6.4005e-04 - val_loss: 0.0011
#
# Epoch 00059: val_loss did not improve from 0.00082
# Epoch 60/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 6.3344e-04 - val_loss: 0.0011
#
# Epoch 00060: val_loss did not improve from 0.00082
# Epoch 61/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 6.2618e-04 - val_loss: 0.0011
#
# Epoch 00061: val_loss did not improve from 0.00082
# Epoch 62/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 6.1586e-04 - val_loss: 0.0011
#
# Epoch 00062: val_loss did not improve from 0.00082
# Epoch 63/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.8524e-04 - val_loss: 0.0011
#
# Epoch 00063: val_loss did not improve from 0.00082
# Epoch 64/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 6.0477e-04 - val_loss: 0.0011
#
# Epoch 00064: val_loss did not improve from 0.00082
# Epoch 65/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.7180e-04 - val_loss: 0.0011
#
# Epoch 00065: val_loss did not improve from 0.00082
# Epoch 66/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.6993e-04 - val_loss: 0.0011
#
# Epoch 00066: val_loss did not improve from 0.00082
# Epoch 67/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.4375e-04 - val_loss: 0.0011
#
# Epoch 00067: val_loss did not improve from 0.00082
# Epoch 68/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.3027e-04 - val_loss: 0.0011
#
# Epoch 00068: val_loss did not improve from 0.00082
# Epoch 69/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.2028e-04 - val_loss: 0.0011
#
# Epoch 00069: val_loss did not improve from 0.00082
# Epoch 70/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.2001e-04 - val_loss: 0.0011
#
# Epoch 00070: val_loss did not improve from 0.00082
# Epoch 71/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.0066e-04 - val_loss: 0.0011
#
# Epoch 00071: val_loss did not improve from 0.00082
# Epoch 72/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.9804e-04 - val_loss: 0.0011
#
# Epoch 00072: val_loss did not improve from 0.00082
# Epoch 73/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.9148e-04 - val_loss: 0.0011
#
# Epoch 00073: val_loss did not improve from 0.00082
# Epoch 74/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.7827e-04 - val_loss: 0.0011
#
# Epoch 00074: val_loss did not improve from 0.00082
# Epoch 75/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.5179e-04 - val_loss: 0.0011
#
# Epoch 00075: val_loss did not improve from 0.00082
# Epoch 76/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.4519e-04 - val_loss: 0.0011
#
# Epoch 00076: val_loss did not improve from 0.00082
# Epoch 77/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.3091e-04 - val_loss: 0.0011
#
# Epoch 00077: val_loss did not improve from 0.00082
# Epoch 78/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.2800e-04 - val_loss: 0.0011
#
# Epoch 00078: val_loss did not improve from 0.00082
# Epoch 79/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 4.2373e-04 - val_loss: 0.0011
#
# Epoch 00079: val_loss did not improve from 0.00082
# Epoch 80/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.0830e-04 - val_loss: 0.0011
#
# Epoch 00080: val_loss did not improve from 0.00082
# Epoch 81/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.9670e-04 - val_loss: 0.0011
#
# Epoch 00081: val_loss did not improve from 0.00082
# Epoch 82/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.9526e-04 - val_loss: 0.0011
#
# Epoch 00082: val_loss did not improve from 0.00082
# Epoch 83/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.9011e-04 - val_loss: 0.0011
#
# Epoch 00083: val_loss did not improve from 0.00082
# Epoch 84/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.8182e-04 - val_loss: 0.0011
#
# Epoch 00084: val_loss did not improve from 0.00082
# Epoch 85/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.7894e-04 - val_loss: 0.0011
#
# Epoch 00085: val_loss did not improve from 0.00082
# Epoch 86/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.6424e-04 - val_loss: 0.0011
#
# Epoch 00086: val_loss did not improve from 0.00082
# Epoch 87/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.5813e-04 - val_loss: 0.0011
#
# Epoch 00087: val_loss did not improve from 0.00082
# Epoch 88/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.5458e-04 - val_loss: 0.0011
#
# Epoch 00088: val_loss did not improve from 0.00082
# Epoch 89/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.5066e-04 - val_loss: 0.0011
#
# Epoch 00089: val_loss did not improve from 0.00082
# Epoch 90/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.4549e-04 - val_loss: 0.0011
#
# Epoch 00090: val_loss did not improve from 0.00082
# Epoch 91/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.4456e-04 - val_loss: 0.0011
#
# Epoch 00091: val_loss did not improve from 0.00082
# Epoch 92/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.3088e-04 - val_loss: 0.0011
#
# Epoch 00092: val_loss did not improve from 0.00082
# Epoch 93/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.3413e-04 - val_loss: 0.0011
#
# Epoch 00093: val_loss did not improve from 0.00082
# Epoch 94/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.1680e-04 - val_loss: 0.0011
#
# Epoch 00094: val_loss did not improve from 0.00082
# Epoch 95/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.1279e-04 - val_loss: 0.0011
#
# Epoch 00095: val_loss did not improve from 0.00082
# Epoch 96/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.0088e-04 - val_loss: 0.0011
#
# Epoch 00096: val_loss did not improve from 0.00082
# Epoch 97/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.0603e-04 - val_loss: 0.0011
#
# Epoch 00097: val_loss did not improve from 0.00082
# Epoch 98/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.0290e-04 - val_loss: 0.0011
#
# Epoch 00098: val_loss did not improve from 0.00082
# Epoch 99/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.9063e-04 - val_loss: 0.0011
#
# Epoch 00099: val_loss did not improve from 0.00082
# Epoch 100/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.8716e-04 - val_loss: 0.0011
#
# Epoch 00100: val_loss did not improve from 0.00082
# Epoch 101/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.8038e-04 - val_loss: 0.0011
#
# Epoch 00101: val_loss did not improve from 0.00082
# Epoch 102/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.7540e-04 - val_loss: 0.0011
#
# Epoch 00102: val_loss did not improve from 0.00082
# Epoch 103/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.8035e-04 - val_loss: 0.0011
#
# Epoch 00103: val_loss did not improve from 0.00082
# Epoch 104/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.6517e-04 - val_loss: 0.0011
#
# Epoch 00104: val_loss did not improve from 0.00082
# Epoch 105/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.5959e-04 - val_loss: 0.0011
#
# Epoch 00105: val_loss did not improve from 0.00082
# Epoch 106/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.6313e-04 - val_loss: 0.0011
#
# Epoch 00106: val_loss did not improve from 0.00082
# Epoch 107/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.5916e-04 - val_loss: 0.0011
#
# Epoch 00107: val_loss did not improve from 0.00082
# Epoch 108/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.5284e-04 - val_loss: 0.0011
#
# Epoch 00108: val_loss did not improve from 0.00082
# Epoch 109/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4780e-04 - val_loss: 0.0011
#
# Epoch 00109: val_loss did not improve from 0.00082
# Epoch 110/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.5653e-04 - val_loss: 0.0011
#
# Epoch 00110: val_loss did not improve from 0.00082
# Epoch 111/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4919e-04 - val_loss: 0.0011
#
# Epoch 00111: val_loss did not improve from 0.00082
# Epoch 112/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4828e-04 - val_loss: 0.0011
#
# Epoch 00112: val_loss did not improve from 0.00082
# Epoch 113/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4401e-04 - val_loss: 0.0011
#
# Epoch 00113: val_loss did not improve from 0.00082
# Epoch 114/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 2.4074e-04 - val_loss: 0.0011
#
# Epoch 00114: val_loss did not improve from 0.00082
# Epoch 115/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4255e-04 - val_loss: 0.0011
#
# Epoch 00115: val_loss did not improve from 0.00082
# Epoch 116/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3337e-04 - val_loss: 0.0011
#
# Epoch 00116: val_loss did not improve from 0.00082
# Epoch 117/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3362e-04 - val_loss: 0.0011
#
# Epoch 00117: val_loss did not improve from 0.00082
# Epoch 118/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.2705e-04 - val_loss: 0.0011
#
# Epoch 00118: val_loss did not improve from 0.00082
# Epoch 119/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.2179e-04 - val_loss: 0.0011
#
# Epoch 00119: val_loss did not improve from 0.00082
# Epoch 120/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.2124e-04 - val_loss: 0.0011
#
# Epoch 00120: val_loss did not improve from 0.00082
# Epoch 121/150
#  192/1712 [==>...........................] - ETA: 11s - loss: 2.2664e-04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-6b8d2bb12594> in <module>()
#       6                        points_train_f,
#       7                        validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
# ----> 8                        shuffle=True, epochs=150, verbose=1)
#       9 # save the model weights
#      10 model.save_weights('weights.h5')
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1176                                         steps_per_epoch=steps_per_epoch,
#    1177                                         validation_steps=validation_steps,
# -> 1178                                         validation_freq=validation_freq)
#    1179
#    1180     def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     202                     ins_batch[i] = ins_batch[i].toarray()
#     203
# --> 204                 outs = fit_function(ins_batch)
#     205                 outs = to_list(outs)
#     206                 for l, o in zip(out_labels, outs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2977                     return self._legacy_call(inputs)
#    2978
# -> 2979             return self._call(inputs)
#    2980         else:
#    2981             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2935             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2936         else:
# -> 2937             fetched = self._callable_fn(*array_vals)
#    2938         return fetched[:len(self.outputs)]
#    2939
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
# 水平翻轉 (horizontal)
img_flip = imgs_test[::-1, :, :]

fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(img_flip.reshape(img_flip.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(img_flip[i], np.squeeze(points_test[i]))
